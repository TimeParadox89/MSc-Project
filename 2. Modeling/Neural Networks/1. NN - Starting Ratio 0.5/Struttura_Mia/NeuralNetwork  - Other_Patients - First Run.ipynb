# %% [markdown]
# # <center><b><h1>NeuralNetwork (First Run)</h1></b></center>

# %%
import itertools
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from math import cos, sin, atan
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.externals import joblib
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, r2_score, recall_score, auc, roc_auc_score, roc_curve
from sklearn.metrics import classification_report,confusion_matrix, precision_score
from sklearn.neural_network import MLPClassifier
from scipy.stats import spearmanr, pearsonr

# %% [markdown]
# ## 1. Prepare the data

# %%
df_X_train = pd.read_csv("../../../Data/other_patients/X_train.csv", index_col=0)
df_X_train.shape
# Out:
# (300, 14)

# %%
df_y_train = pd.read_csv("../../../Data/other_patients/y_train.csv", index_col=0)
df_y_train.shape
# Out:
# (300, 1)

# %%
df_X_val = pd.read_csv("../../../Data/other_patients/X_val.csv", index_col=0)
df_X_val.shape
# Out:
# (20734, 14)

# %%
df_y_val = pd.read_csv("../../../Data/other_patients/y_val.csv", index_col=0)
df_y_val.shape
# Out:
# (20734, 1)

# %%
neural_network_name = 'NeuralNetwork - Other_Patients - First Run - Base Ratio 05'

# %% [markdown]
# ## 2. Finding the best number of layers (between 1 and 2) and the best number of neurons

# %% [markdown]
# ### 2.1 AUC based

# %%
max_n_neurons = df_X_train.shape[1] * 2 + 1
max_n_randomstate = 100

# %%
best_score_sl = actual_score = 0
best_i_sl = 0
for i in range(1,max_n_neurons,1):
    mlp = MLPClassifier(hidden_layer_sizes=(i,), max_iter=200000,verbose=False)
    mlp.fit(df_X_train,df_y_train['Class'].values)
    predictions = mlp.predict(df_X_val.values)
    fpr, tpr, thresholds = roc_curve(df_y_val['Class'].values, predictions, pos_label=1)
    actual_score = auc(fpr, tpr)
    if actual_score > best_score_sl:
        best_score_sl = actual_score
        best_i_sl = i
    print("I: ", i, "Best_I: ",best_i_sl,"Best_Score: ", best_score_sl,"Actual_Score: ", actual_score)
print("Best_I: ",best_i_sl,"Best_Score: ", best_score_sl)
# Out:
# I:  1 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.6488991888760139
# I:  2 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5
# I:  3 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5744188700445942
# I:  4 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5378722040801995
# I:  5 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5878147055725272
# I:  6 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.6233255205590085
# I:  7 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5546960040731767
# I:  8 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.6234198883387759
# I:  9 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5864979458548404
# I:  10 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5172912496927561
# I:  11 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5126079742968503
# I:  12 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.49707459882720606
# I:  13 Best_I:  1 Best_Score:  0.6488991888760139 Actual_Score:  0.5245553741353277
# I:  14 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.6551625759331438
# I:  15 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.48991581516204924
# I:  16 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5690925769865516
# I:  17 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5458100705783209
# I:  18 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5178201481793602
# I:  19 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5257141226868921
# I:  20 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5180374135327785
# I:  21 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5150922609642192
# I:  22 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5604261034446435
# I:  23 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5222620176270234
# I:  24 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5689960146072545
# I:  25 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5259072474454861
# I:  26 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5078873907089434
# I:  27 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5315802872291864
# I:  28 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5852777485164506
# I:  29 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5484172548193407
# I:  30 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5640230520734577
# I:  31 Best_I:  14 Best_Score:  0.6551625759331438 Actual_Score:  0.5285868534709786
# Best_I:  14 Best_Score:  0.6551625759331438

# %%
best_score_twol = actual_score = 0
best_i_twol = best_j_twol = 0
for i in range(1,max_n_neurons,1):
    for j in range(1,max_n_neurons,1):
        mlp = MLPClassifier(hidden_layer_sizes=(i,j,), max_iter=200000,verbose=False)
        mlp.fit(df_X_train,df_y_train['Class'].values)
        predictions = mlp.predict(df_X_val.values)
        fpr, tpr, thresholds = roc_curve(df_y_val['Class'].values, predictions, pos_label=1)
        actual_score = auc(fpr, tpr)
        if actual_score > best_score_twol:
            best_score_twol = actual_score
            best_i_twol = i
            best_j_twol = j
        print("I,J: ", i,"-",j)
    print("Best_I: ", best_i_twol,"Best_J: ", best_j_twol,"Best_Score: ", best_score_twol,"Actual_Score: ", actual_score)
print("Best_I: ",best_i_twol,"Best_I: ",best_j_twol,"Best_Score: ", best_score_twol)
# Out:
# I,J:  1 - 1
# I,J:  1 - 2
# I,J:  1 - 3
# I,J:  1 - 4
# I,J:  1 - 5
# I,J:  1 - 6
# I,J:  1 - 7
# I,J:  1 - 8
# I,J:  1 - 9
# I,J:  1 - 10
# I,J:  1 - 11
# I,J:  1 - 12
# I,J:  1 - 13
# I,J:  1 - 14
# I,J:  1 - 15
# I,J:  1 - 16
# I,J:  1 - 17
# I,J:  1 - 18
# I,J:  1 - 19
# I,J:  1 - 20
# I,J:  1 - 21
# I,J:  1 - 22
# I,J:  1 - 23
# I,J:  1 - 24
# I,J:  1 - 25
# I,J:  1 - 26
# I,J:  1 - 27
# I,J:  1 - 28
# I,J:  1 - 29
# I,J:  1 - 30
# I,J:  1 - 31
# Best_I:  1 Best_J:  31 Best_Score:  0.5808512412654938 Actual_Score:  0.5808512412654938
# I,J:  2 - 1
# I,J:  2 - 2
# I,J:  2 - 3
# I,J:  2 - 4
# I,J:  2 - 5
# I,J:  2 - 6
# I,J:  2 - 7
# I,J:  2 - 8
- 31
# Best_I:  5 Best_J:  18 Best_Score:  0.6727830155553214 Actual_Score:  0.5462687418799818
# I,J:  30 - 1
# I,J:  30 - 2
# I,J:  30 - 3
# I,J:  30 - 4
# I,J:  30 - 5
# I,J:  30 - 6
# I,J:  30 - 7
# I,J:  30 - 8
# I,J:  30 - 9
# I,J:  30 - 10
# I,J:  30 - 11
# I,J:  30 - 12
# I,J:  30 - 13
# I,J:  30 - 14
# I,J:  30 - 15
# I,J:  30 - 16
# I,J:  30 - 17
# I,J:  30 - 18
# I,J:  30 - 19
# I,J:  30 - 20
# I,J:  30 - 21
# I,J:  30 - 22
# I,J:  30 - 23
# I,J:  30 - 24
# I,J:  30 - 25
# I,J:  30 - 26
# I,J:  30 - 27
# I,J:  30 - 28
# I,J:  30 - 29
# I,J:  30 - 30
# I,J:  30 - 31
# Best_I:  5 Best_J:  18 Best_Score:  0.6727830155553214 Actual_Score:  0.47960778117209174
# I,J:  31 - 1
# I,J:  31 - 2
# I,J:  31 - 3
# I,J:  31 - 4
# I,J:  31 - 5
# I,J:  31 - 6
# I,J:  31 - 7
# I,J:  31 - 8
# I,J:  31 - 9
# I,J:  31 - 10
# I,J:  31 - 11
# I,J:  31 - 12
# I,J:  31 - 13
# I,J:  31 - 14
# I,J:  31 - 15
# I,J:  31 - 16
# I,J:  31 - 17
# I,J:  31 - 18
# I,J:  31 - 19
# I,J:  31 - 20
# I,J:  31 - 21
# I,J:  31 - 22
# I,J:  31 - 23
# I,J:  31 - 24
# I,J:  31 - 25
# I,J:  31 - 26
# I,J:  31 - 27
# I,J:  31 - 28
# I,J:  31 - 29
# I,J:  31 - 30
# I,J:  31 - 31
# Best_I:  5 Best_J:  18 Best_Score:  0.6727830155553214 Actual_Score:  0.5724722602619474
# Best_I:  5 Best_I:  18 Best_Score:  0.6727830155553214

# %% [markdown]
# ## 3 Find the best random state for both single layer and two layers

# %%
best_score_sl = actual_score = 0
best_random_state_sl = 0
for i in range(1,max_n_randomstate,1):
    mlp = MLPClassifier(hidden_layer_sizes=(best_i_sl,), max_iter=200000,verbose=False, random_state=i)
    mlp.fit(df_X_train,df_y_train['Class'].values)
    predictions = mlp.predict(df_X_val.values)
    fpr, tpr, thresholds = roc_curve(df_y_val['Class'].values, predictions, pos_label=1)
    actual_score = auc(fpr, tpr)
    if actual_score > best_score_sl:
        best_score_sl = actual_score
        best_random_state_sl = i
    print("I: ", i, "Best_Random_State: ",best_random_state_sl,"Best_Score: ", best_score_sl,"Actual_Score: ", actual_score)
print("Best_Random_State: ",best_random_state_sl,"Best_Score: ", best_score_sl)
# Out:
# I:  1 Best_Random_State:  1 Best_Score:  0.5392328557884758 Actual_Score:  0.5392328557884758
# I:  2 Best_Random_State:  2 Best_Score:  0.5646748481337126 Actual_Score:  0.5646748481337126
# I:  3 Best_Random_State:  2 Best_Score:  0.5646748481337126 Actual_Score:  0.5212371396467572
# I:  4 Best_Random_State:  4 Best_Score:  0.574041398925524 Actual_Score:  0.574041398925524
# I:  5 Best_Random_State:  5 Best_Score:  0.5798351416833456 Actual_Score:  0.5798351416833456
# I:  6 Best_Random_State:  6 Best_Score:  0.5919054390954739 Actual_Score:  0.5919054390954739
# I:  7 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.615043101934759
# I:  8 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.6084285789529127
# I:  9 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5900948944836546
# I:  10 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.501924663787352
# I:  11 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5100732118403034
# I:  12 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5247726394887461
# I:  13 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5622739562484639
# I:  14 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5686097650900664
# I:  15 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.4883949576881211
# I:  16 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.517833315776537
# I:  17 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5404398855296885
# I:  18 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.540584729098634
# I:  19 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5090812528529793
# I:  20 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5747173355806032
# I:  21 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.6089596720390463
# I:  22 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5438195688050844
# I:  23 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5732206187014994
# I:  24 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5556001790793216
# I:  25 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5487442501492327
# I:  26 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5260652586116086
# I:  27 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5602461462832263
# I:  28 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5661715650128165
# I:  29 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.6063042066083781
# I:  30 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0.5617428631623301
# I:  31 Best_Random_State:  7 Best_Score:  0.615043101934759 Actual_Score:  0
Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6607039397450754
# I:  36 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4345877664243828
# I:  37 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.511991291829067
# I:  38 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6227900382738157
# I:  39 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5601978650935777
# I:  40 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4951543242389129
# I:  41 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5590040029495418
# I:  42 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5265239299132695
# I:  43 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5731723375118508
# I:  44 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5529556866463009
# I:  45 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5589184135678922
# I:  46 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6473059096176129
# I:  47 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4851732855788476
# I:  48 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.550361670002458
# I:  49 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5919778608799466
# I:  50 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5167930755995647
# I:  51 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5498898311036203
# I:  52 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5782769760174163
# I:  53 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5865089188524878
# I:  54 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.505111222304154
# I:  55 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5787970961059026
# I:  56 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5355042311878928
# I:  57 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5844218546999544
# I:  58 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5495869763685524
# I:  59 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6075112363495909
# I:  60 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.593329734190105
# I:  61 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.59154333017311
# I:  62 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.47438243969240496
# I:  63 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.47598669194845317
# I:  64 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4745623968538221
# I:  65 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4724753327012887
# I:  66 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5764927665999509
# I:  67 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5370009480669967
# I:  68 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5561049369711015
# I:  69 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4986788510832543
# I:  70 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5635051265845009
# I:  71 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5570837283612486
# I:  72 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6240102356122055
# I:  73 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5463170230696304
# I:  74 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5297082938305419
# I:  75 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6521691421749358
# I:  76 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.44335299694511743
# I:  77 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.564047192668282
# I:  78 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5823216229502441
# I:  79 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.546692299589171
# I:  80 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5886705993890236
# I:  81 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5850495101653851
# I:  82 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5142605077425471
# I:  83 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4833122651778503
# I:  84 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5265239299132695
# I:  85 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6011249517188103
# I:  86 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.47962094876926864
# I:  87 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.6250373081920012
# I:  88 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5161544471364865
# I:  89 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5410302328031181
# I:  90 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5423601601179816
# I:  91 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5387368762948138
# I:  92 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5610910671020753
# I:  93 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.50222751852242
# I:  94 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5534384985427859
# I:  95 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5190535131149268
# I:  96 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.4677064679237332
# I:  97 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5639989114786335
# I:  98 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.572075037747112
# I:  99 Best_Random_State:  35 Best_Score:  0.6607039397450754 Actual_Score:  0.5260893992064328
# Best_Random_State:  35 Best_Score:  0.6607039397450754

# %% [markdown]
# ## 4. Compute metrics on the best architecture

# %%
if (best_score_sl > 0.5) and (best_score_sl > best_score_twol):
    best_architecture = "One Layer"
    best_neurons = [best_i_sl]
    mlp = MLPClassifier(hidden_layer_sizes=(best_i_sl,), max_iter=200000,verbose=False, random_state=best_random_state_sl)
    mlp.fit(df_X_train,df_y_train['Class'].values)
elif best_score_twol > 0.5:
    best_architecture = "Two Layers"
    best_neurons = [best_i_twol, best_j_twol]
    mlp = MLPClassifier(hidden_layer_sizes=(best_i_twol,best_j_twol), max_iter=200000,verbose=False, random_state=best_random_state_twol)
    mlp.fit(df_X_train,df_y_train['Class'].values)
else:
    print("The auc value is below the threshold of 0.5 and it means that there aren't good NN with 1 or 2 hidden layers architecture")

predictions = mlp.predict(df_X_val.values)
print("The best architecture is : ", best_architecture)
layer = 0
for neuron in best_neurons:
    layer += 1
    print("For the hidden layer ", layer, " the best number of neurons is : ", neuron)
# Out:
# The best architecture is :  Two Layers
# For the hidden layer  1  the best number of neurons is :  5
# For the hidden layer  2  the best number of neurons is :  18

# %% [markdown]
# ### 4.1 Confusion Matrix and Classification Report

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
conf_mat = confusion_matrix(df_y_val['Class'].values,predictions)
tn, fp, fn, tp = conf_mat.ravel()

np.set_printoptions(precision=2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"],
                      title='Confusion matrix')
plt.savefig(neural_network_name+'_confusion_matrix.png', bbox_inches="tight")

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"], normalize=True,
                      title='Normalized confusion matrix')
plt.savefig(neural_network_name+'_confusion_matrix_normalized.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix
# [[17013  3699]
#  [   11    11]]
# Normalized confusion matrix
# [[0.82 0.18]
#  [0.5  0.5 ]]

# %%
print(classification_report(df_y_val['Class'].values,predictions,target_names=['Non-Fracture','Fracture']))
# Out:
#               precision    recall  f1-score   support
#
# Non-Fracture       1.00      0.82      0.90     20712
#     Fracture       0.00      0.50      0.01        22
#
#    micro avg       0.82      0.82      0.82     20734
#    macro avg       0.50      0.66      0.45     20734
# weighted avg       1.00      0.82      0.90     20734

# %% [markdown]
# ### 4.2 Accuracy

# %%
accuracy = (tp + tn) / float(tp+tn+fp+fn)
print("Accuracy : ",accuracy)
# Out:
# Accuracy :  0.8210668467251857

# %% [markdown]
# ### 4.3 Recall (or Sensitivity)

# %%
recall = tp/(tp+fn)
print("Recall : ", recall)
# Out:
# Recall :  0.5

# %% [markdown]
# ### 4.4 Error

# %%
classification_error = (fp + fn) / float(tp+tn+fp+fn)
print("Error : ",classification_error)
# Out:
# Error :  0.17893315327481432

# %% [markdown]
# ### 4.5 Specificity

# %%
specificity = tn / (tn+fp)

print(specificity)
# Out:
# 0.8214078794901506

# %% [markdown]
# ### 4.6 False Positive Rate: When the actual value is negative, how often is the prediction incorrect?

# %%
false_positive_rate = fp / float(tn+fp)

print(false_positive_rate)
print(1 - specificity)
# Out:
# 0.17859212050984935
# 0.1785921205098494

# %% [markdown]
# ### 4.7 Precision: When a positive value is predicted, how often is the prediction correct?

# %%
precision = tp / float(tp+fp)

print(precision)
# Out:
# 0.0029649595687331535

# %% [markdown]
# ## 5. Metrics visualization

# %%
fpr, tpr, thresholds = roc_curve(df_y_val, predictions)

plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ## 6. Neural Network Visualization

# %%
class Neuron():
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def draw(self, neuron_radius):
        circle = plt.Circle((self.x, self.y), radius=neuron_radius, fill=False)
        plt.gca().add_patch(circle)


class Layer():
    def __init__(self, network, number_of_neurons, number_of_neurons_in_widest_layer):
        self.vertical_distance_between_layers = 6
        self.horizontal_distance_between_neurons = 2
        self.neuron_radius = 0.5
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.previous_layer = self.__get_previous_layer(network)
        self.y = self.__calculate_layer_y_position()
        self.neurons = self.__intialise_neurons(number_of_neurons)

    def __intialise_neurons(self, number_of_neurons):
        neurons = []
        x = self.__calculate_left_margin_so_layer_is_centered(number_of_neurons)
        for iteration in range(number_of_neurons):
            neuron = Neuron(x, self.y)
            neurons.append(neuron)
            x += self.horizontal_distance_between_neurons
        return neurons

    def __calculate_left_margin_so_layer_is_centered(self, number_of_neurons):
        return self.horizontal_distance_between_neurons * (self.number_of_neurons_in_widest_layer - number_of_neurons) / 2

    def __calculate_layer_y_position(self):
        if self.previous_layer:
            return self.previous_layer.y + self.vertical_distance_between_layers
        else:
            return 0

    def __get_previous_layer(self, network):
        if len(network.layers) > 0:
            return network.layers[-1]
        else:
            return None

    def __line_between_two_neurons(self, neuron1, neuron2):
        angle = atan((neuron2.x - neuron1.x) / float(neuron2.y - neuron1.y))
        x_adjustment = self.neuron_radius * sin(angle)
        y_adjustment = self.neuron_radius * cos(angle)
        line = plt.Line2D((neuron1.x - x_adjustment, neuron2.x + x_adjustment), (neuron1.y - y_adjustment, neuron2.y + y_adjustment))
        plt.gca().add_line(line)

    def draw(self, layerType=0):
        for neuron in self.neurons:
            neuron.draw( self.neuron_radius )
            if self.previous_layer:
                for previous_layer_neuron in self.previous_layer.neurons:
                    self.__line_between_two_neurons(neuron, previous_layer_neuron)
        # write Text
        x_text = self.number_of_neurons_in_widest_layer * self.horizontal_distance_between_neurons
        if layerType == 0:
            plt.text(x_text, self.y, 'Input Layer', fontsize = 12)
        elif layerType == -1:
            plt.text(x_text, self.y, 'Output Layer', fontsize = 12)
        else:
            plt.text(x_text, self.y, 'Hidden Layer '+str(layerType), fontsize = 12)

class NeuralNetwork():
    def __init__(self, number_of_neurons_in_widest_layer):
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.layers = []
        self.layertype = 0

    def add_layer(self, number_of_neurons ):
        layer = Layer(self, number_of_neurons, self.number_of_neurons_in_widest_layer)
        self.layers.append(layer)

    def draw(self):
        plt.figure(figsize=(38,8), dpi=300)
        for i in range( len(self.layers) ):
            layer = self.layers[i]
            if i == len(self.layers)-1:
                i = -1
            layer.draw( i )
        plt.axis('scaled')
        plt.axis('off')
        plt.title( 'Neural Network architecture', fontsize=15 )
        plt.savefig(neural_network_name+'_network.png', bbox_inches="tight")
        plt.show()

class DrawNN():
    def __init__( self, neural_network ):
        self.neural_network = neural_network

    def draw( self ):
        widest_layer = max( self.neural_network )
        network = NeuralNetwork( widest_layer )
        for l in self.neural_network:
            network.add_layer(l)
        network.draw()

# %%
n_input = df_X_train.shape[1]
n_output = 1
if best_score_sl > best_score_twol:
    nn_structure = [n_input, best_i_sl, n_output]
else:
    nn_structure = [n_input, best_i_twol, best_j_twol, n_output]    
neural_network = DrawNN( nn_structure )
neural_network.draw()

# %% [markdown]
# ## 7. Creation new dataframe

# %%
mod_df = pd.DataFrame(df_X_val)

# %%
mod_df.head()
# Out:
#              sex       age    weight    height      HIPX   smoking  \
# 151086  0.971362  0.773403  0.605963  2.151512 -0.037838  2.330176
# 127949  0.971362  0.152632 -0.344003 -0.024365 -0.037838 -0.808640
# 43792   0.971362  0.400940  1.466671  0.737192 -0.037838 -0.808640
# 52828   0.971362  1.518328 -1.561745 -0.133159 -0.037838  0.760768
# 100732 -1.029482 -1.833836 -1.485238 -0.568335 -0.037838  0.760768
#
#         ReumatoidArthritis  SecondaryOsteoporsis   Alcohol  VitaminD  \
# 151086            -0.08895             -0.134216 -0.787198  0.746591
# 127949            -0.08895             -0.134216 -0.037842 -0.185478
# 43792             -0.08895             -0.134216 -0.788571 -0.196359
# 52828             -0.08895             -0.134216 -0.582578 -0.522764
# 100732            -0.08895             -0.134216  0.004272 -0.780262
#
#          calcium  dose_walk  dose_moderate  dose_vigorous
# 151086  0.316228  -0.493062      -0.313105      -0.168681
# 127949 -0.288672  -0.559852       0.782642       2.052902
# 43792   0.915187  -0.392877      -0.512332      -0.477234
# 52828   0.692015  -0.337219      -0.263298      -0.538945
# 100732  1.328364   0.208233       6.709640      -0.168681

# %%
mod_df['real_class'] = df_y_val
mod_df['predicted_class'] = predictions

# %%
mod_df.head()
# Out:
#              sex       age    weight    height      HIPX   smoking  \
# 151086  0.971362  0.773403  0.605963  2.151512 -0.037838  2.330176
# 127949  0.971362  0.152632 -0.344003 -0.024365 -0.037838 -0.808640
# 43792   0.971362  0.400940  1.466671  0.737192 -0.037838 -0.808640
# 52828   0.971362  1.518328 -1.561745 -0.133159 -0.037838  0.760768
# 100732 -1.029482 -1.833836 -1.485238 -0.568335 -0.037838  0.760768
#
#         ReumatoidArthritis  SecondaryOsteoporsis   Alcohol  VitaminD  \
# 151086            -0.08895             -0.134216 -0.787198  0.746591
# 127949            -0.08895             -0.134216 -0.037842 -0.185478
# 43792             -0.08895             -0.134216 -0.788571 -0.196359
# 52828             -0.08895             -0.134216 -0.582578 -0.522764
# 100732            -0.08895             -0.134216  0.004272 -0.780262
#
#          calcium  dose_walk  dose_moderate  dose_vigorous  real_class  \
# 151086  0.316228  -0.493062      -0.313105      -0.168681           0
# 127949 -0.288672  -0.559852       0.782642       2.052902           0
# 43792   0.915187  -0.392877      -0.512332      -0.477234           0
# 52828   0.692015  -0.337219      -0.263298      -0.538945           0
# 100732  1.328364   0.208233       6.709640      -0.168681           0
#
#         predicted_class
# 151086                1
# 127949                0
# 43792                 0
# 52828                 0
# 100732                0

# %%
mod_df_complete = mod_df[(mod_df['real_class'] == 0) & ( mod_df['predicted_class']==1)]

# %%
mod_df_complete['Class'] = mod_df['real_class']
mod_df_complete = mod_df_complete.drop(['real_class','predicted_class'],axis=1)
mod_df_complete.shape
# Out:
# /Users/erennio/anaconda2/envs/Python36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# (3699, 15)

# %%
std_patients = pd.read_csv('../../../Data/standardized_patients.csv', index_col=0)
std_patients = std_patients[std_patients['menopause']<1]
std_patients.drop(columns=['menopause','HRT'], axis=1, inplace=True)
std_patients.shape
# Out:
# (103669, 15)

# %% [markdown]
# ### 6.1 Check Equivalence

# %%
for index in mod_df_complete.index.values:
    equals = True
    patient = std_patients.loc[index].round(10) == mod_df_complete.loc[index].round(10)
    for feature in patient:
        if not feature:
            equals = False
            print(std_patients.loc[index].round(10) == giorgiONE.loc[index].round(10), index)
    if equals:
        std_patients.loc[index,'Class'] = 1

# %%
std_patients.loc[mod_df_complete.index.values,'Class'].shape
# Out:
# (3699,)

# %%
std_patients.to_csv('../../../Data/other_patients/new_std_patients.csv')

# %% [markdown]
# ## 7. Save the model

# %%
joblib.dump(mlp, neural_network_name+'_model.pkl')
# Out:
# ['NeuralNetwork - Other_Patients - First Run - Base Ratio 05_model.pkl']
