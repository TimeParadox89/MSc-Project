# %% [markdown]
# # <center><b><h1>NeuralNetwork (First Run)</h1></b></center>

# %%
import itertools
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from math import cos, sin, atan
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.externals import joblib
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, r2_score, recall_score, auc, roc_auc_score, roc_curve
from sklearn.metrics import classification_report,confusion_matrix, precision_score
from sklearn.neural_network import MLPClassifier
from scipy.stats import spearmanr, pearsonr

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## 1. Prepare the data

# %%
df_X_train = pd.read_csv("../../../Data/women_menopause/starting_ratio_05/X_train.csv", index_col=0)
df_X_train.shape
# Out:
# (192, 14)

# %%
df_y_train = pd.read_csv("../../../Data/women_menopause/starting_ratio_05/y_train.csv", index_col=0)
df_y_train.shape
# Out:
# (192, 1)

# %%
df_X_val = pd.read_csv("../../../Data/women_menopause/X_val.csv", index_col=0)
df_X_val.shape
# Out:
# (10043, 14)

# %%
df_y_val = pd.read_csv("../../../Data/women_menopause/y_val.csv", index_col=0)
df_y_val.shape
# Out:
# (10043, 1)

# %%
neural_network_name = 'NeuralNetwork - Women_Menopause - First Run - Base Ratio 05'

# %% [markdown]
# ## 2. Finding the best number of layers (between 1 and 2) and the best number of neurons

# %% [markdown]
# ### 2.1 AUC based

# %% [markdown]
# # 0.5 because auc below 0.5 is not good, i have to quote the paper

# %%
max_n_neurons = df_X_train.shape[1] * 2 + 1
max_n_randomstate = 100

# %%
best_score_sl = actual_score = 0
best_i_sl = 0
for i in range(1,max_n_neurons,1):
    mlp = MLPClassifier(hidden_layer_sizes=(i,), max_iter=200000,verbose=False)
    mlp.fit(df_X_train,df_y_train['Class'].values)
    predictions = mlp.predict(df_X_val.values)
    fpr, tpr, thresholds = roc_curve(df_y_val['Class'].values, predictions, pos_label=1)
    actual_score = auc(fpr, tpr)
    if actual_score > best_score_sl:
        best_score_sl = actual_score
        best_i_sl = i
    print("I: ", i, "Best_I: ",best_i_sl,"Best_Score: ", best_score_sl,"Actual_Score: ", actual_score)
print("Best_I: ",best_i_sl,"Best_Score: ", best_score_sl)
# Out:
# I:  1 Best_I:  1 Best_Score:  0.5132980634857257 Actual_Score:  0.5132980634857257
# I:  2 Best_I:  1 Best_Score:  0.5132980634857257 Actual_Score:  0.4995228588540627
# I:  3 Best_I:  3 Best_Score:  0.532086244759433 Actual_Score:  0.532086244759433
# I:  4 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.5584467957676184
# I:  5 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.46638251147933724
# I:  6 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.5265462168097425
# I:  7 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.5242723098422839
# I:  8 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.46977041325613894
# I:  9 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.5354242363745259
# I:  10 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.5320303453783191
# I:  11 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.4543262128169295
# I:  12 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.4998522659213416
# I:  13 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.4510820523058494
# I:  14 Best_I:  4 Best_Score:  0.5584467957676184 Actual_Score:  0.49133160311439406
# I:  15 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5759592733080455
# I:  16 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.545392293871032
# I:  17 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.44544220403274104
# I:  18 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5351607107207027
# I:  19 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5102335795567977
# I:  20 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5130285486124975
# I:  21 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5488860051906568
# I:  22 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.4984687562387701
# I:  23 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5451427430624874
# I:  24 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5210860451187861
# I:  25 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.4837452585346377
# I:  26 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5357097224995008
# I:  27 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5321800758634458
# I:  28 Best_I:  15 Best_Score:  0.5759592733080455 Actual_Score:  0.5148253144340188
# Best_I:  15 Best_Score:  0.5759592733080455

# %%
best_score_twol = actual_score = 0
best_i_twol = best_j_twol = 0
for i in range(1,max_n_neurons,1):
    for j in range(1,max_n_neurons,1):
        mlp = MLPClassifier(hidden_layer_sizes=(i,j,), max_iter=200000,verbose=False)
        mlp.fit(df_X_train,df_y_train['Class'].values)
        predictions = mlp.predict(df_X_val.values)
        fpr, tpr, thresholds = roc_curve(df_y_val['Class'].values, predictions, pos_label=1)
        actual_score = auc(fpr, tpr)
        if actual_score > best_score_twol:
            best_score_twol = actual_score
            best_i_twol = i
            best_j_twol = j
        print("I,J: ", i,"-",j)
    print("Best_I: ", best_i_twol,"Best_J: ", best_j_twol,"Best_Score: ", best_score_twol,"Actual_Score: ", actual_score)
print("Best_I: ",best_i_twol,"Best_I: ",best_j_twol,"Best_Score: ", best_score_twol)
# Out:
# I,J:  1 - 1
# I,J:  1 - 2
# I,J:  1 - 3
# I,J:  1 - 4
# I,J:  1 - 5
# I,J:  1 - 6
# I,J:  1 - 7
# I,J:  1 - 8
# I,J:  1 - 9
# I,J:  1 - 10
# I,J:  1 - 11
# I,J:  1 - 12
# I,J:  1 - 13
# I,J:  1 - 14
# I,J:  1 - 15
# I,J:  1 - 16
# I,J:  1 - 17
# I,J:  1 - 18
# I,J:  1 - 19
# I,J:  1 - 20
# I,J:  1 - 21
# I,J:  1 - 22
# I,J:  1 - 23
# I,J:  1 - 24
# I,J:  1 - 25
# I,J:  1 - 26
# I,J:  1 - 27
# I,J:  1 - 28
# Best_I:  1 Best_J:  14 Best_Score:  0.5711459373128368 Actual_Score:  0.49386105010980236
# I,J:  2 - 1
# I,J:  2 - 2
# I,J:  2 - 3
# I,J:  2 - 4
# I,J:  2 - 5
# I,J:  2 - 6
# I,J:  2 - 7
# I,J:  2 - 8
# I,J:  2 - 9
# I,J:  2 - 10
# I,J:  2 - 11
# I,J:  2 - 12
# I,J:  2 - 13
# I,J:  2 - 14
# I,J:  2 - 15
# I,J:  2 - 16
# I,J:  2 - 17
# I,J:  2 - 18
# I,J:  2 - 19
# I,J:  2 - 20
# I,J:  2 - 21
# I,J:  2 - 22
# I,J:  2 - 23
# I,J:  2 - 24
# I,J:  2 - 25
# I,J:  2 - 26
# I,J:  2 - 27
# I,J:  2 - 28
# Best_I:  1 Best_J:  14 Best_Score:  0.5711459373128368 Actual_Score:  0.49480934318227193
# I,J:  3 - 1
# I,J:  3 - 2
# I,J:  3 - 3
# I,J:  3 - 4
# I,J:  3 - 5
# I,J:  3 - 6
# I,J:  3 - 7
# I,J:  3 - 8
# I,J:  3 - 9
# I,J:  3 - 10
# I,J:  3 - 11
# I,J:  3 - 12
# I,J:  3 - 13
# I,J:  3 - 14
# I,J:  3 - 15
# I,J:  3 - 16
# I,J:  3 - 17
# I,J:  3 - 18
# I,J:  3 - 19
# I,J:  3 - 20
# I,J:  3 - 21
# I,J:  3 - 22
# I,J:  3 - 23
# I,J:  3 - 24
# I,J:  3 - 25
# I,J:  3 - 26
# I,J:  3 - 27
# I,J:  3 - 28
# Best_I:  3 Best_J:  10 Best_Score:  0.5908884008784189 Actual_Score:  0.5470533040527051
# I,J:  4 - 1
# I,J:  4 - 2
# I,J:  4 - 3
# I,J:  4 - 4
# I,J:  4 - 5
# I,J:  4 - 6
# I,J:  4 - 7
# I,J:  4 - 8
# I,J:  4 - 9
# I,J:  4 - 10
# I,J:  4 - 11
# I,J:  4 - 12
# I,J:  4 - 13
# I,J:  4 - 14
# I,J:  4 - 15
# I,J:  4 - 16
# I,J:  4 - 17
# I,J:  4 - 18
# I,J:  4 - 19
# I,J:  4 - 20
# I,J:  4 - 21
# I,J:  4 - 22
# I,J:  4 - 23
# I,J:  4 - 24
# I,J:  4 - 25
# I,J:  4 - 26
# I,J:  4 - 27
# I,J:  4 - 28
# Best_I:  4 Best_J:  8 Best_Score:  0.6101976442403673 Actual_Score:  0.4882591335595927
# I,J:  5 - 1
# I,J:  5 - 2
# I,J:  5 - 3
# I,J:  5 - 4
# I,J:  5 - 5
# I,J:  5 - 6
# I,J:  5 - 7
# I,J:  5 - 8
# I,J:  5 - 9
# I,J:  5 - 10
# I,J:  5 - 11
# I,J:  5 - 12
# I,J:  5 - 13
# I,J:  5 - 14
# I,J:  5 - 15
# I,J:  5 - 16
# I,J:  5 - 17
# I,J:  5 - 18
# I,J:  5 - 19
# I,J:  5 - 20
# I,J:  5 - 21
# I,J:  5 - 22
# I,J:  5 - 23
# I,J:  5 - 24
# I,J:  5 - 25
# I,J:  5 - 26
# I,J:  5 - 27
# I,J:  5 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.45780594929127577
# I,J:  6 - 1
# I,J:  6 - 2
# I,J:  6 - 3
# I,J:  6 - 4
# I,J:  6 - 5
# I,J:  6 - 6
# I,J:  6 - 7
# I,J:  6 - 8
# I,J:  6 - 9
# I,J:  6 - 10
# I,J:  6 - 11
# I,J:  6 - 12
# I,J:  6 - 13
# I,J:  6 - 14
# I,J:  6 - 15
# I,J:  6 - 16
# I,J:  6 - 17
# I,J:  6 - 18
# I,J:  6 - 19
# I,J:  6 - 20
# I,J:  6 - 21
# I,J:  6 - 22
# I,J:  6 - 23
# I,J:  6 - 24
# I,J:  6 - 25
# I,J:  6 - 26
# I,J:  6 - 27
# I,J:  6 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.545777600319425
# I,J:  7 - 1
# I,J:  7 - 2
# I,J:  7 - 3
# I,J:  7 - 4
# I,J:  7 - 5
# I,J:  7 - 6
# I,J:  7 - 7
# I,J:  7 - 8
# I,J:  7 - 9
# I,J:  7 - 10
# I,J:  7 - 11
# I,J:  7 - 12
# I,J:  7 - 13
# I,J:  7 - 14
# I,J:  7 - 15
# I,J:  7 - 16
# I,J:  7 - 17
# I,J:  7 - 18
# I,J:  7 - 19
# I,J:  7 - 20
# I,J:  7 - 21
# I,J:  7 - 22
# I,J:  7 - 23
# I,J:  7 - 24
# I,J:  7 - 25
# I,J:  7 - 26
# I,J:  7 - 27
# I,J:  7 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.4977560391295668
# I,J:  8 - 1
# I,J:  8 - 2
# I,J:  8 - 3
# I,J:  8 - 4
# I,J:  8 - 5
# I,J:  8 - 6
# I,J:  8 - 7
# I,J:  8 - 8
# I,J:  8 - 9
# I,J:  8 - 10
# I,J:  8 - 11
# I,J:  8 - 12
# I,J:  8 - 13
# I,J:  8 - 14
# I,J:  8 - 15
# I,J:  8 - 16
# I,J:  8 - 17
# I,J:  8 - 18
# I,J:  8 - 19
# I,J:  8 - 20
# I,J:  8 - 21
# I,J:  8 - 22
# I,J:  8 - 23
# I,J:  8 - 24
# I,J:  8 - 25
# I,J:  8 - 26
# I,J:  8 - 27
# I,J:  8 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5884587742064284
# I,J:  9 - 1
# I,J:  9 - 2
# I,J:  9 - 3
# I,J:  9 - 4
# I,J:  9 - 5
# I,J:  9 - 6
# I,J:  9 - 7
# I,J:  9 - 8
# I,J:  9 - 9
# I,J:  9 - 10
# I,J:  9 - 11
# I,J:  9 - 12
# I,J:  9 - 13
# I,J:  9 - 14
# I,J:  9 - 15
# I,J:  9 - 16
# I,J:  9 - 17
# I,J:  9 - 18
# I,J:  9 - 19
# I,J:  9 - 20
# I,J:  9 - 21
# I,J:  9 - 22
# I,J:  9 - 23
# I,J:  9 - 24
# I,J:  9 - 25
# I,J:  9 - 26
# I,J:  9 - 27
# I,J:  9 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.4857276901577161
# I,J:  10 - 1
# I,J:  10 - 2
# I,J:  10 - 3
# I,J:  10 - 4
# I,J:  10 - 5
# I,J:  10 - 6
# I,J:  10 - 7
# I,J:  10 - 8
# I,J:  10 - 9
# I,J:  10 - 10
# I,J:  10 - 11
# I,J:  10 - 12
# I,J:  10 - 13
# I,J:  10 - 14
# I,J:  10 - 15
# I,J:  10 - 16
# I,J:  10 - 17
# I,J:  10 - 18
# I,J:  10 - 19
# I,J:  10 - 20
# I,J:  10 - 21
# I,J:  10 - 22
# I,J:  10 - 23
# I,J:  10 - 24
# I,J:  10 - 25
# I,J:  10 - 26
# I,J:  10 - 27
# I,J:  10 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5027969654621681
# I,J:  11 - 1
# I,J:  11 - 2
# I,J:  11 - 3
# I,J:  11 - 4
# I,J:  11 - 5
# I,J:  11 - 6
# I,J:  11 - 7
# I,J:  11 - 8
# I,J:  11 - 9
# I,J:  11 - 10
# I,J:  11 - 11
# I,J:  11 - 12
# I,J:  11 - 13
# I,J:  11 - 14
# I,J:  11 - 15
# I,J:  11 - 16
# I,J:  11 - 17
# I,J:  11 - 18
# I,J:  11 - 19
# I,J:  11 - 20
# I,J:  11 - 21
# I,J:  11 - 22
# I,J:  11 - 23
# I,J:  11 - 24
# I,J:  11 - 25
# I,J:  11 - 26
# I,J:  11 - 27
# I,J:  11 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5175563984827312
# I,J:  12 - 1
# I,J:  12 - 2
# I,J:  12 - 3
# I,J:  12 - 4
# I,J:  12 - 5
# I,J:  12 - 6
# I,J:  12 - 7
# I,J:  12 - 8
# I,J:  12 - 9
# I,J:  12 - 10
# I,J:  12 - 11
# I,J:  12 - 12
# I,J:  12 - 13
# I,J:  12 - 14
# I,J:  12 - 15
# I,J:  12 - 16
# I,J:  12 - 17
# I,J:  12 - 18
# I,J:  12 - 19
# I,J:  12 - 20
# I,J:  12 - 21
# I,J:  12 - 22
# I,J:  12 - 23
# I,J:  12 - 24
# I,J:  12 - 25
# I,J:  12 - 26
# I,J:  12 - 27
# I,J:  12 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5679017768017568
# I,J:  13 - 1
# I,J:  13 - 2
# I,J:  13 - 3
# I,J:  13 - 4
# I,J:  13 - 5
# I,J:  13 - 6
# I,J:  13 - 7
# I,J:  13 - 8
# I,J:  13 - 9
# I,J:  13 - 10
# I,J:  13 - 11
# I,J:  13 - 12
# I,J:  13 - 13
# I,J:  13 - 14
# I,J:  13 - 15
# I,J:  13 - 16
# I,J:  13 - 17
# I,J:  13 - 18
# I,J:  13 - 19
# I,J:  13 - 20
# I,J:  13 - 21
# I,J:  13 - 22
# I,J:  13 - 23
# I,J:  13 - 24
# I,J:  13 - 25
# I,J:  13 - 26
# I,J:  13 - 27
# I,J:  13 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.4197384707526452
# I,J:  14 - 1
# I,J:  14 - 2
# I,J:  14 - 3
# I,J:  14 - 4
# I,J:  14 - 5
# I,J:  14 - 6
# I,J:  14 - 7
# I,J:  14 - 8
# I,J:  14 - 9
# I,J:  14 - 10
# I,J:  14 - 11
# I,J:  14 - 12
# I,J:  14 - 13
# I,J:  14 - 14
# I,J:  14 - 15
# I,J:  14 - 16
# I,J:  14 - 17
# I,J:  14 - 18
# I,J:  14 - 19
# I,J:  14 - 20
# I,J:  14 - 21
# I,J:  14 - 22
# I,J:  14 - 23
# I,J:  14 - 24
# I,J:  14 - 25
# I,J:  14 - 26
# I,J:  14 - 27
# I,J:  14 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.4398023557596326
# I,J:  15 - 1
# I,J:  15 - 2
# I,J:  15 - 3
# I,J:  15 - 4
# I,J:  15 - 5
# I,J:  15 - 6
# I,J:  15 - 7
# I,J:  15 - 8
# I,J:  15 - 9
# I,J:  15 - 10
# I,J:  15 - 11
# I,J:  15 - 12
# I,J:  15 - 13
# I,J:  15 - 14
# I,J:  15 - 15
# I,J:  15 - 16
# I,J:  15 - 17
# I,J:  15 - 18
# I,J:  15 - 19
# I,J:  15 - 20
# I,J:  15 - 21
# I,J:  15 - 22
# I,J:  15 - 23
# I,J:  15 - 24
# I,J:  15 - 25
# I,J:  15 - 26
# I,J:  15 - 27
# I,J:  15 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5181912557396685
# I,J:  16 - 1
# I,J:  16 - 2
# I,J:  16 - 3
# I,J:  16 - 4
# I,J:  16 - 5
# I,J:  16 - 6
# I,J:  16 - 7
# I,J:  16 - 8
# I,J:  16 - 9
# I,J:  16 - 10
# I,J:  16 - 11
# I,J:  16 - 12
# I,J:  16 - 13
# I,J:  16 - 14
# I,J:  16 - 15
# I,J:  16 - 16
# I,J:  16 - 17
# I,J:  16 - 18
# I,J:  16 - 19
# I,J:  16 - 20
# I,J:  16 - 21
# I,J:  16 - 22
# I,J:  16 - 23
# I,J:  16 - 24
# I,J:  16 - 25
# I,J:  16 - 26
# I,J:  16 - 27
# I,J:  16 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5515172689159512
# I,J:  17 - 1
# I,J:  17 - 2
# I,J:  17 - 3
# I,J:  17 - 4
# I,J:  17 - 5
# I,J:  17 - 6
# I,J:  17 - 7
# I,J:  17 - 8
# I,J:  17 - 9
# I,J:  17 - 10
# I,J:  17 - 11
# I,J:  17 - 12
# I,J:  17 - 13
# I,J:  17 - 14
# I,J:  17 - 15
# I,J:  17 - 16
# I,J:  17 - 17
# I,J:  17 - 18
# I,J:  17 - 19
# I,J:  17 - 20
# I,J:  17 - 21
# I,J:  17 - 22
# I,J:  17 - 23
# I,J:  17 - 24
# I,J:  17 - 25
# I,J:  17 - 26
# I,J:  17 - 27
# I,J:  17 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5550109802355759
# I,J:  18 - 1
# I,J:  18 - 2
# I,J:  18 - 3
# I,J:  18 - 4
# I,J:  18 - 5
# I,J:  18 - 6
# I,J:  18 - 7
# I,J:  18 - 8
# I,J:  18 - 9
# I,J:  18 - 10
# I,J:  18 - 11
# I,J:  18 - 12
# I,J:  18 - 13
# I,J:  18 - 14
# I,J:  18 - 15
# I,J:  18 - 16
# I,J:  18 - 17
# I,J:  18 - 18
# I,J:  18 - 19
# I,J:  18 - 20
# I,J:  18 - 21
# I,J:  18 - 22
# I,J:  18 - 23
# I,J:  18 - 24
# I,J:  18 - 25
# I,J:  18 - 26
# I,J:  18 - 27
# I,J:  18 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5558235176681972
# I,J:  19 - 1
# I,J:  19 - 2
# I,J:  19 - 3
# I,J:  19 - 4
# I,J:  19 - 5
# I,J:  19 - 6
# I,J:  19 - 7
# I,J:  19 - 8
# I,J:  19 - 9
# I,J:  19 - 10
# I,J:  19 - 11
# I,J:  19 - 12
# I,J:  19 - 13
# I,J:  19 - 14
# I,J:  19 - 15
# I,J:  19 - 16
# I,J:  19 - 17
# I,J:  19 - 18
# I,J:  19 - 19
# I,J:  19 - 20
# I,J:  19 - 21
# I,J:  19 - 22
# I,J:  19 - 23
# I,J:  19 - 24
# I,J:  19 - 25
# I,J:  19 - 26
# I,J:  19 - 27
# I,J:  19 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.49101816729886205
# I,J:  20 - 1
# I,J:  20 - 2
# I,J:  20 - 3
# I,J:  20 - 4
# I,J:  20 - 5
# I,J:  20 - 6
# I,J:  20 - 7
# I,J:  20 - 8
# I,J:  20 - 9
# I,J:  20 - 10
# I,J:  20 - 11
# I,J:  20 - 12
# I,J:  20 - 13
# I,J:  20 - 14
# I,J:  20 - 15
# I,J:  20 - 16
# I,J:  20 - 17
# I,J:  20 - 18
# I,J:  20 - 19
# I,J:  20 - 20
# I,J:  20 - 21
# I,J:  20 - 22
# I,J:  20 - 23
# I,J:  20 - 24
# I,J:  20 - 25
# I,J:  20 - 26
# I,J:  20 - 27
# I,J:  20 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5267758035536034
# I,J:  21 - 1
# I,J:  21 - 2
# I,J:  21 - 3
# I,J:  21 - 4
# I,J:  21 - 5
# I,J:  21 - 6
# I,J:  21 - 7
# I,J:  21 - 8
# I,J:  21 - 9
# I,J:  21 - 10
# I,J:  21 - 11
# I,J:  21 - 12
# I,J:  21 - 13
# I,J:  21 - 14
# I,J:  21 - 15
# I,J:  21 - 16
# I,J:  21 - 17
# I,J:  21 - 18
# I,J:  21 - 19
# I,J:  21 - 20
# I,J:  21 - 21
# I,J:  21 - 22
# I,J:  21 - 23
# I,J:  21 - 24
# I,J:  21 - 25
# I,J:  21 - 26
# I,J:  21 - 27
# I,J:  21 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.548786184867239
# I,J:  22 - 1
# I,J:  22 - 2
# I,J:  22 - 3
# I,J:  22 - 4
# I,J:  22 - 5
# I,J:  22 - 6
# I,J:  22 - 7
# I,J:  22 - 8
# I,J:  22 - 9
# I,J:  22 - 10
# I,J:  22 - 11
# I,J:  22 - 12
# I,J:  22 - 13
# I,J:  22 - 14
# I,J:  22 - 15
# I,J:  22 - 16
# I,J:  22 - 17
# I,J:  22 - 18
# I,J:  22 - 19
# I,J:  22 - 20
# I,J:  22 - 21
# I,J:  22 - 22
# I,J:  22 - 23
# I,J:  22 - 24
# I,J:  22 - 25
# I,J:  22 - 26
# I,J:  22 - 27
# I,J:  22 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5283869035735675
# I,J:  23 - 1
# I,J:  23 - 2
# I,J:  23 - 3
# I,J:  23 - 4
# I,J:  23 - 5
# I,J:  23 - 6
# I,J:  23 - 7
# I,J:  23 - 8
# I,J:  23 - 9
# I,J:  23 - 10
# I,J:  23 - 11
# I,J:  23 - 12
# I,J:  23 - 13
# I,J:  23 - 14
# I,J:  23 - 15
# I,J:  23 - 16
# I,J:  23 - 17
# I,J:  23 - 18
# I,J:  23 - 19
# I,J:  23 - 20
# I,J:  23 - 21
# I,J:  23 - 22
# I,J:  23 - 23
# I,J:  23 - 24
# I,J:  23 - 25
# I,J:  23 - 26
# I,J:  23 - 27
# I,J:  23 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5403513675384308
# I,J:  24 - 1
# I,J:  24 - 2
# I,J:  24 - 3
# I,J:  24 - 4
# I,J:  24 - 5
# I,J:  24 - 6
# I,J:  24 - 7
# I,J:  24 - 8
# I,J:  24 - 9
# I,J:  24 - 10
# I,J:  24 - 11
# I,J:  24 - 12
# I,J:  24 - 13
# I,J:  24 - 14
# I,J:  24 - 15
# I,J:  24 - 16
# I,J:  24 - 17
# I,J:  24 - 18
# I,J:  24 - 19
# I,J:  24 - 20
# I,J:  24 - 21
# I,J:  24 - 22
# I,J:  24 - 23
# I,J:  24 - 24
# I,J:  24 - 25
# I,J:  24 - 26
# I,J:  24 - 27
# I,J:  24 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5053922938710321
# I,J:  25 - 1
# I,J:  25 - 2
# I,J:  25 - 3
# I,J:  25 - 4
# I,J:  25 - 5
# I,J:  25 - 6
# I,J:  25 - 7
# I,J:  25 - 8
# I,J:  25 - 9
# I,J:  25 - 10
# I,J:  25 - 11
# I,J:  25 - 12
# I,J:  25 - 13
# I,J:  25 - 14
# I,J:  25 - 15
# I,J:  25 - 16
# I,J:  25 - 17
# I,J:  25 - 18
# I,J:  25 - 19
# I,J:  25 - 20
# I,J:  25 - 21
# I,J:  25 - 22
# I,J:  25 - 23
# I,J:  25 - 24
# I,J:  25 - 25
# I,J:  25 - 26
# I,J:  25 - 27
# I,J:  25 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5817987622279895
# I,J:  26 - 1
# I,J:  26 - 2
# I,J:  26 - 3
# I,J:  26 - 4
# I,J:  26 - 5
# I,J:  26 - 6
# I,J:  26 - 7
# I,J:  26 - 8
# I,J:  26 - 9
# I,J:  26 - 10
# I,J:  26 - 11
# I,J:  26 - 12
# I,J:  26 - 13
# I,J:  26 - 14
# I,J:  26 - 15
# I,J:  26 - 16
# I,J:  26 - 17
# I,J:  26 - 18
# I,J:  26 - 19
# I,J:  26 - 20
# I,J:  26 - 21
# I,J:  26 - 22
# I,J:  26 - 23
# I,J:  26 - 24
# I,J:  26 - 25
# I,J:  26 - 26
# I,J:  26 - 27
# I,J:  26 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.546689958075464
# I,J:  27 - 1
# I,J:  27 - 2
# I,J:  27 - 3
# I,J:  27 - 4
# I,J:  27 - 5
# I,J:  27 - 6
# I,J:  27 - 7
# I,J:  27 - 8
# I,J:  27 - 9
# I,J:  27 - 10
# I,J:  27 - 11
# I,J:  27 - 12
# I,J:  27 - 13
# I,J:  27 - 14
# I,J:  27 - 15
# I,J:  27 - 16
# I,J:  27 - 17
# I,J:  27 - 18
# I,J:  27 - 19
# I,J:  27 - 20
# I,J:  27 - 21
# I,J:  27 - 22
# I,J:  27 - 23
# I,J:  27 - 24
# I,J:  27 - 25
# I,J:  27 - 26
# I,J:  27 - 27
# I,J:  27 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5452924735476142
# I,J:  28 - 1
# I,J:  28 - 2
# I,J:  28 - 3
# I,J:  28 - 4
# I,J:  28 - 5
# I,J:  28 - 6
# I,J:  28 - 7
# I,J:  28 - 8
# I,J:  28 - 9
# I,J:  28 - 10
# I,J:  28 - 11
# I,J:  28 - 12
# I,J:  28 - 13
# I,J:  28 - 14
# I,J:  28 - 15
# I,J:  28 - 16
# I,J:  28 - 17
# I,J:  28 - 18
# I,J:  28 - 19
# I,J:  28 - 20
# I,J:  28 - 21
# I,J:  28 - 22
# I,J:  28 - 23
# I,J:  28 - 24
# I,J:  28 - 25
# I,J:  28 - 26
# I,J:  28 - 27
# I,J:  28 - 28
# Best_I:  5 Best_J:  20 Best_Score:  0.6362088241165902 Actual_Score:  0.5051926532241965
# Best_I:  5 Best_I:  20 Best_Score:  0.6362088241165902

# %% [markdown]
# ## 3 Find the best random state for both single layer and two layers

# %%
best_score_sl = actual_score = 0
best_random_state_sl = 0
for i in range(1,max_n_randomstate,1):
    mlp = MLPClassifier(hidden_layer_sizes=(best_i_sl,), max_iter=200000,verbose=False, random_state=i)
    mlp.fit(df_X_train,df_y_train['Class'].values)
    predictions = mlp.predict(df_X_val.values)
    fpr, tpr, thresholds = roc_curve(df_y_val['Class'].values, predictions, pos_label=1)
    actual_score = auc(fpr, tpr)
    if actual_score > best_score_sl:
        best_score_sl = actual_score
        best_random_state_sl = i
    print("I: ", i, "Best_Random_State: ",best_random_state_sl,"Best_Score: ", best_score_sl,"Actual_Score: ", actual_score)
print("Best_Random_State: ",best_random_state_sl,"Best_Score: ", best_score_sl)
# Out:
# I:  1 Best_Random_State:  1 Best_Score:  0.5238810141744858 Actual_Score:  0.5238810141744858
# I:  2 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.6019484927131163
# I:  3 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.5204651627071272
# I:  4 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.534026751846676
# I:  5 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.4941625074865242
# I:  6 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.5093351966460371
# I:  7 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.5157097224995009
# I:  8 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.4648931922539429
# I:  9 Best_Random_State:  2 Best_Score:  0.6019484927131163 Actual_Score:  0.5762727091235775
# I:  10 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.6055420243561589
# I:  11 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5024116590137752
# I:  12 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.4839448991814733
# I:  13 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5108325014973049
# I:  14 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.4975064883210222
# I:  15 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5250928329007787
# I:  16 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5404511878618486
# I:  17 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.4950608903972849
# I:  18 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5272249950089838
# I:  19 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5171710920343382
# I:  20 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.49231583150329405
# I:  21 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.4853922938710321
# I:  22 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5162227989618686
# I:  23 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5342763026552206
# I:  24 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5293212218007586
# I:  25 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5249930125773608
# I:  26 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.561599121581154
# I:  27 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5611000199640647
# I:  28 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.568786184867239
# I:  29 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5362587342782991
# I:  30 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5685226592134158
# I:  31 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.4752106208824116
# I:  32 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5318806148931923
# I:  33 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5314174485925334
# I:  34 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5118806148931923
# I:  35 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.47081852665202634
# I:  36 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5061908564583749
# I:  37 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.45886803753244154
# I:  38 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5524795368336993
# I:  39 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.47647234977041325
# I:  40 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.537969654621681
# I:  41 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5708325014973049
# I:  42 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5542124176482331
# I:  43 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5080734677580355
# I:  44 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5067897783988821
# I:  45 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5035456178878019
# I:  46 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5341125973248153
# I:  47 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5376701936514274
# I:  48 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5096346576162907
# I:  49 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5140626871631064
# I:  50 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5603014573767219
# I:  51 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5412497504491913
# I:  52 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.52224795368337
# I:  53 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.49151726891595127
# I:  54 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.4552605310441206
# I:  55 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.5550109802355759
# I:  56 Best_Random_State:  10 Best_Score:  0.6055420243561589 Actual_Score:  0.45795567977640245
# I:  57 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.6521161908564584
# I:  58 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.508137352765023
# I:  59 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5344619684567777
# I:  60 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.4947115192653224
# I:  61 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5112317827909763
# I:  62 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5129147534438012
# I:  63 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5320662806947494
# I:  64 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5752245957276901
# I:  65 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.4941625074865242
# I:  66 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.4780055899381114
# I:  67 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.49043322020363345
# I:  68 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.49068277101217805
# I:  69 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.502846875623877
# I:  70 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.519652625274506
# I:  71 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.49021960471151926
# I:  72 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5395028947893791
# I:  73 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5158594529846278
# I:  74 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.513663405869435
# I:  75 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.46872229986025155
# I:  76 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.4890217608305051
# I:  77 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.587774006787782
# I:  78 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.49317827909762424
# I:  79 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5608504691555201
# I:  80 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5045438211219805
# I:  81 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.45086843681373523
# I:  82 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5041445398283091
# I:  83 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5101696945498103
# I:  84 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.494961070073867
# I:  85 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5177560391295668
# I:  86 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.4891854661609104
# I:  87 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.4624475943302056
# I:  88 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5376422439608703
# I:  89 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5092353763226193
# I:  90 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5018486723896985
# I:  91 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5195388301058095
# I:  92 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.4971571171890597
# I:  93 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.47522459572769016
# I:  94 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5395168696346576
# I:  95 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.46752445597923736
# I:  96 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5424975044919145
# I:  97 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.47183070473148336
# I:  98 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.5340127770013974
# I:  99 Best_Random_State:  57 Best_Score:  0.6521161908564584 Actual_Score:  0.49336394489918145
# Best_Random_State:  57 Best_Score:  0.6521161908564584

# %%
best_score_twol = actual_score = 0
best_random_state_twol = 0
for i in range(1,max_n_randomstate,1):
    mlp = MLPClassifier(hidden_layer_sizes=(best_i_twol,best_j_twol), max_iter=200000,verbose=False, random_state=i)
    mlp.fit(df_X_train,df_y_train['Class'].values)
    predictions = mlp.predict(df_X_val.values)
    fpr, tpr, thresholds = roc_curve(df_y_val['Class'].values, predictions, pos_label=1)
    actual_score = auc(fpr, tpr)
    if actual_score > best_score_twol:
        best_score_twol = actual_score
        best_random_state_twol = i
    print("I: ", i, "Best_Random_State: ",best_random_state_twol,"Best_Score: ", best_score_twol,"Actual_Score: ", actual_score)
print("Best_Random_State: ",best_random_state_twol,"Best_Score: ", best_score_twol)
# Out:
# I:  1 Best_Random_State:  1 Best_Score:  0.4702695148732282 Actual_Score:  0.4702695148732282
# I:  2 Best_Random_State:  1 Best_Score:  0.4702695148732282 Actual_Score:  0.4609363146336594
# I:  3 Best_Random_State:  3 Best_Score:  0.5011000199640647 Actual_Score:  0.5011000199640647
# I:  4 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.5570932321820723
# I:  5 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.4965222599321222
# I:  6 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.498255140746656
# I:  7 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.4821481333599521
# I:  8 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.48124975044919144
# I:  9 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.427774006787782
# I:  10 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.4825833499700539
# I:  11 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.5514174485925334
# I:  12 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.4527370732681174
# I:  13 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.47932521461369537
# I:  14 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.5419345178678379
# I:  15 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.4818127370732681
# I:  16 Best_Random_State:  4 Best_Score:  0.5570932321820723 Actual_Score:  0.5131283689359154
# I:  17 Best_Random_State:  17 Best_Score:  0.5875384308245158 Actual_Score:  0.5875384308245158
# I:  18 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.6197524455979238
# I:  19 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5740626871631064
# I:  20 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5131643042523458
# I:  21 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5425833499700539
# I:  22 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5012856857656219
# I:  23 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5269395088840088
# I:  24 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.4573427829906169
# I:  25 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.4978917947694151
# I:  26 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.531018167298862
# I:  27 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5245298462767018
# I:  28 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5478598522659213
# I:  29 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5125653823118387
# I:  30 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5442942703134358
# I:  31 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5685226592134158
# I:  32 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5289219405070872
# I:  33 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.4937772010381314
# I:  34 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.4838810141744859
# I:  35 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5605010980235576
# I:  36 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.46159912158115396
# I:  37 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5400738670393292
# I:  38 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5400379317228987
# I:  39 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5059772409662607
# I:  40 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.47893990816530246
# I:  41 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.522561389498902
# I:  42 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5078518666400479
# I:  43 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.4757097224995009
# I:  44 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.518903972848872
# I:  45 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5040946296666001
# I:  46 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5331782790976243
# I:  47 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5317169095627869
# I:  48 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.542483529646636
# I:  49 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5201517268915952
# I:  50 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5089219405070873
# I:  51 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5278738271111998
# I:  52 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5570712717109203
# I:  53 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.520251547215013
# I:  54 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5637951686963465
# I:  55 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5048293072469555
# I:  56 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5152824915152725
# I:  57 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.6057057296865642
# I:  58 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5013855060890398
# I:  59 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5602515472150129
# I:  60 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5040307446596127
# I:  61 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.49419844280295466
# I:  62 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5024336194849272
# I:  63 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.529435016969455
# I:  64 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5443302056298662
# I:  65 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5349111599121581
# I:  66 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5425334398083449
# I:  67 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.4944120582950689
# I:  68 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5704691555200638
# I:  69 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5343262128169295
# I:  70 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5466759832301856
# I:  71 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.550033938909962
# I:  72 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5026971451387503
# I:  73 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5023337991615093
# I:  74 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.48080055899381113
# I:  75 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.47650828508684373
# I:  76 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.520301457376722
# I:  77 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5300978239169495
# I:  78 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5313316031143941
# I:  79 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5544899181473348
# I:  80 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5711539229387104
# I:  81 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.4615352365741665
# I:  82 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.5153603513675384
# I:  83 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.45888999800359354
# I:  84 Best_Random_State:  18 Best_Score:  0.6197524455979238 Actual_Score:  0.492365741665003
# I:  85 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.6394669594729487
# I:  86 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.4710960271511279
# I:  87 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5053783190257537
# I:  88 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5038810141744859
# I:  89 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5040946296666001
# I:  90 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5129786384507886
# I:  91 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5541764823318027
# I:  92 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.4642942703134358
# I:  93 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5234457975643841
# I:  94 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5183409862247953
# I:  95 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.49286484328209224
# I:  96 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5079237372729088
# I:  97 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5958095428229188
# I:  98 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.514675583948892
# I:  99 Best_Random_State:  85 Best_Score:  0.6394669594729487 Actual_Score:  0.5164583749251348
# Best_Random_State:  85 Best_Score:  0.6394669594729487

# %% [markdown]
# ## 4. Compute metrics on the best architecture

# %%
if (best_score_sl > 0.5) and (best_score_sl > best_score_twol):
    best_architecture = "One Layer"
    best_neurons = [best_i_sl]
    mlp = MLPClassifier(hidden_layer_sizes=(best_i_sl,), max_iter=200000,verbose=False, random_state=best_random_state_sl)
    mlp.fit(df_X_train,df_y_train['Class'].values)
elif best_score_twol > 0.5:
    best_architecture = "Two Layers"
    best_neurons = [best_i_twol, best_j_twol]
    mlp = MLPClassifier(hidden_layer_sizes=(best_i_twol,best_j_twol), max_iter=200000,verbose=False, random_state=best_random_state_twol)
    mlp.fit(df_X_train,df_y_train['Class'].values)
else:
    print("The auc value is below the threshold of 0.5 and it means that there aren't good NN with 1 or 2 hidden layers architecture")

predictions = mlp.predict(df_X_val.values)
print("The best architecture is : ", best_architecture)
layer = 0
for neuron in best_neurons:
    layer += 1
    print("For the hidden layer ", layer, " the best number of neurons is : ", neuron)
# Out:
# The best architecture is :  One Layer
# For the hidden layer  1  the best number of neurons is :  15

# %% [markdown]
# ### 4.1 Confusion Matrix and Classification Report

# %%
conf_mat_base_folder = '../../../Data/confusion_matrix/neural_network/women_menopause/base_ratio_05/'

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
conf_mat = confusion_matrix(df_y_val['Class'].values,predictions)
tn, fp, fn, tp = conf_mat.ravel()

# %%
conf_mat_df = pd.DataFrame([list(pd.Series([tn, fp, fn, tp]))],columns=['tn', 'fp', 'fn', 'tp'])
conf_mat_df.columns.names = ['model']
conf_mat_df.rename(index={0: 'All_Patients'},inplace=True)
conf_mat_df
# Out:
# model           tn    fp  fn  tp
# All_Patients  7055  2963  10  15

# %%
np.set_printoptions(precision=2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"],
                      title='Confusion matrix')
plt.savefig(conf_mat_base_folder+neural_network_name+'_confusion_matrix.png', bbox_inches="tight")

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"], normalize=True,
                      title='Normalized confusion matrix')
plt.savefig(conf_mat_base_folder+neural_network_name+'_confusion_matrix_normalized.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix
# [[7055 2963]
#  [  10   15]]
# Normalized confusion matrix
# [[0.7 0.3]
#  [0.4 0.6]]

# %%
print(classification_report(df_y_val['Class'].values,predictions,target_names=['Non-Fracture','Fracture']))
# Out:
#               precision    recall  f1-score   support
#
# Non-Fracture       1.00      0.70      0.83     10018
#     Fracture       0.01      0.60      0.01        25
#
#    micro avg       0.70      0.70      0.70     10043
#    macro avg       0.50      0.65      0.42     10043
# weighted avg       1.00      0.70      0.82     10043

# %% [markdown]
# ### 4.2 Accuracy

# %%
accuracy = (tp + tn) / float(tp+tn+fp+fn)
print("Accuracy : ",accuracy)
# Out:
# Accuracy :  0.7039729164592253

# %% [markdown]
# ### 4.3 Recall (or Sensitivity)

# %%
recall = tp/(tp+fn)
print("Recall : ", recall)
# Out:
# Recall :  0.6

# %% [markdown]
# ### 4.4 Error

# %%
classification_error = (fp + fn) / float(tp+tn+fp+fn)
print("Error : ",classification_error)
# Out:
# Error :  0.29602708354077467

# %% [markdown]
# ### 4.5 Specificity

# %%
specificity = tn / (tn+fp)

print(specificity)
# Out:
# 0.7042323817129168

# %% [markdown]
# ### 4.6 False Positive Rate: When the actual value is negative, how often is the prediction incorrect?

# %%
false_positive_rate = fp / float(tn+fp)

print(false_positive_rate)
print(1 - specificity)
# Out:
# 0.29576761828708326
# 0.2957676182870832

# %% [markdown]
# ### 4.7 Precision: When a positive value is predicted, how often is the prediction correct?

# %%
precision = tp / float(tp+fp)

print(precision)
# Out:
# 0.005036937541974479

# %% [markdown]
# ## 5. Metrics visualization

# %%
fpr, tpr, thresholds = roc_curve(df_y_val, predictions)

plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ## 6. Neural Network Visualization

# %%
nn_model_base_folder = '../../../Models/Neural_Networks/women_menopause/base_ratio_05/'

# %%
class Neuron():
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def draw(self, neuron_radius):
        circle = plt.Circle((self.x, self.y), radius=neuron_radius, fill=False)
        plt.gca().add_patch(circle)


class Layer():
    def __init__(self, network, number_of_neurons, number_of_neurons_in_widest_layer):
        self.vertical_distance_between_layers = 6
        self.horizontal_distance_between_neurons = 2
        self.neuron_radius = 0.5
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.previous_layer = self.__get_previous_layer(network)
        self.y = self.__calculate_layer_y_position()
        self.neurons = self.__intialise_neurons(number_of_neurons)

    def __intialise_neurons(self, number_of_neurons):
        neurons = []
        x = self.__calculate_left_margin_so_layer_is_centered(number_of_neurons)
        for iteration in range(number_of_neurons):
            neuron = Neuron(x, self.y)
            neurons.append(neuron)
            x += self.horizontal_distance_between_neurons
        return neurons

    def __calculate_left_margin_so_layer_is_centered(self, number_of_neurons):
        return self.horizontal_distance_between_neurons * (self.number_of_neurons_in_widest_layer - number_of_neurons) / 2

    def __calculate_layer_y_position(self):
        if self.previous_layer:
            return self.previous_layer.y + self.vertical_distance_between_layers
        else:
            return 0

    def __get_previous_layer(self, network):
        if len(network.layers) > 0:
            return network.layers[-1]
        else:
            return None

    def __line_between_two_neurons(self, neuron1, neuron2):
        angle = atan((neuron2.x - neuron1.x) / float(neuron2.y - neuron1.y))
        x_adjustment = self.neuron_radius * sin(angle)
        y_adjustment = self.neuron_radius * cos(angle)
        line = plt.Line2D((neuron1.x - x_adjustment, neuron2.x + x_adjustment), (neuron1.y - y_adjustment, neuron2.y + y_adjustment))
        plt.gca().add_line(line)

    def draw(self, layerType=0):
        n_neurons = 0
        for neuron in self.neurons:
            neuron.draw( self.neuron_radius )
            n_neurons += 1
            if self.previous_layer:
                for previous_layer_neuron in self.previous_layer.neurons:
                    self.__line_between_two_neurons(neuron, previous_layer_neuron)
        # write Text
        x_text = self.number_of_neurons_in_widest_layer * self.horizontal_distance_between_neurons
        if layerType == 0:
            plt.text(x_text, self.y, 'Input Layer', fontsize = 12)
        elif layerType == -1:
            plt.text(x_text, self.y, 'Output Layer', fontsize = 12)
        else:
            plt.text(x_text, self.y, 'Hidden Layer '+str(layerType)+" - "+str(n_neurons)+" neurons", fontsize = 12)

class NeuralNetwork():
    def __init__(self, number_of_neurons_in_widest_layer):
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.layers = []
        self.layertype = 0

    def add_layer(self, number_of_neurons ):
        layer = Layer(self, number_of_neurons, self.number_of_neurons_in_widest_layer)
        self.layers.append(layer)

    def draw(self):
        plt.figure(figsize=(38,8), dpi=300)
        for i in range( len(self.layers) ):
            layer = self.layers[i]
            if i == len(self.layers)-1:
                i = -1
            layer.draw( i )
        plt.axis('scaled')
        plt.axis('off')
        plt.title( 'Neural Network architecture', fontsize=15 )
        plt.savefig(nn_model_base_folder+neural_network_name+'_network.png', bbox_inches="tight")
        plt.show()

class DrawNN():
    def __init__( self, neural_network ):
        self.neural_network = neural_network

    def draw( self ):
        widest_layer = max( self.neural_network )
        network = NeuralNetwork( widest_layer )
        for l in self.neural_network:
            network.add_layer(l)
        network.draw()

# %%
n_input = df_X_train.shape[1]
n_output = 1
if best_score_sl > best_score_twol:
    nn_structure = [n_input, best_i_sl, n_output]
else:
    nn_structure = [n_input, best_i_twol, best_j_twol, n_output]    
neural_network = DrawNN( nn_structure )
neural_network.draw()

# %% [markdown]
# ## 7. Creation new dataframe

# %%
mod_df = df_X_val.copy()

# %%
mod_df['real_class'] = df_y_val
mod_df['predicted_class'] = predictions

# %%
mod_df.head()
# Out:
#              age    weight    height      HIPX       HRT  smoking  \
# 100566  1.021712 -1.580872 -0.894716 -0.037838 -0.423252 -0.80864
# 33140   1.021712 -0.662784 -1.656273 -0.037838 -0.423252 -0.80864
# 32991  -0.095676 -1.147330 -0.133159 -0.037838 -0.423252 -0.80864
# 78811   1.518328  1.460296 -1.547479 -0.037838 -0.423252 -0.80864
# 98941   1.145866 -1.300345 -1.438686 -0.037838 -0.423252 -0.80864
#
#         ReumatoidArthritis  SecondaryOsteoporsis   Alcohol  VitaminD  \
# 100566            -0.08895             -0.134216 -0.788571 -0.809276
# 33140             -0.08895             -0.134216 -0.788571 -0.711354
# 32991             -0.08895             -0.134216  0.255125 -0.743995
# 78811             -0.08895             -0.134216 -0.788571 -0.656953
# 98941             -0.08895             -0.134216 -0.257568  1.334121
#
#          calcium  dose_walk  dose_moderate  dose_vigorous  real_class  \
# 100566  2.053369  -0.548721      -0.562138      -0.045260           0
# 33140  -1.091667   0.208233      -0.163685      -0.538945           0
# 32991   0.112446  -0.058927       1.181096       1.127242           0
# 78811   1.085499  -0.415141      -0.350460       0.571847           0
# 98941  -0.718054  -0.415141      -0.163685      -0.538945           0
#
#         predicted_class
# 100566                0
# 33140                 0
# 32991                 0
# 78811                 1
# 98941                 0

# %%
patients_to_change = mod_df[(mod_df['real_class'] == 0) & ( mod_df['predicted_class']==1)]

# %%
patients_to_change.head()
# Out:
#              age    weight    height      HIPX       HRT   smoking  \
# 78811   1.518328  1.460296 -1.547479 -0.037838 -0.423252 -0.808640
# 117303 -1.213064 -1.000691 -0.241953 -0.037838  2.362657 -0.808640
# 111112  0.897557 -1.395979 -1.112304 -0.037838  2.362657 -0.808640
# 38097   0.649249 -1.019818 -0.677128 -0.037838  2.362657  0.760768
# 68720   0.525095 -0.777545 -0.677128 -0.037838 -0.423252  2.330176
#
#         ReumatoidArthritis  SecondaryOsteoporsis   Alcohol  VitaminD  \
# 78811             -0.08895             -0.134216 -0.788571 -0.656953
# 117303            -0.08895              7.450683 -0.788571 -0.134704
# 111112            -0.08895             -0.134216  0.016631  0.837259
# 38097             -0.08895             -0.134216  0.235441  0.822752
# 68720             -0.08895             -0.134216  1.683341 -0.370442
#
#          calcium  dose_walk  dose_moderate  dose_vigorous  real_class  \
# 78811   1.085499  -0.415141      -0.350460       0.571847           0
# 117303  0.647168   0.074653      -0.238395      -0.538945           0
# 111112 -1.121421  -0.548721       0.583416      -0.168681           0
# 38097  -0.901182  -0.415141      -0.263298      -0.538945           0
# 68720  -1.359205  -0.025532      -0.611945      -0.538945           0
#
#         predicted_class
# 78811                 1
# 117303                1
# 111112                1
# 38097                 1
# 68720                 1

# %%
patients_to_change['possible_fracture_score'] = 0

# %%
costant_weight = -3.876
age_weight = 0.013
sex_weight =0.197
weight_weight = -0.004
height_weight = -0.019
hipx_weight = 2.396
smoking_weight = 0.28
rheumatoidarthritis_weight = 0.766
secondaryosteoporosis_weight = 0.338

# %%
for index,element in patients_to_change.iterrows():
    possible_fracture_score = costant_weight + age_weight * mod_df.loc[index,'age'] +\
                                weight_weight * mod_df.loc[index,'weight'] + height_weight * mod_df.loc[index,'height'] +\
                                hipx_weight * mod_df.loc[index,'HIPX'] + smoking_weight * mod_df.loc[index,'smoking'] +\
                                rheumatoidarthritis_weight * mod_df.loc[index,'ReumatoidArthritis'] +\
                                secondaryosteoporosis_weight * mod_df.loc[index,'SecondaryOsteoporsis']# sex_weight * mod_df.loc[index,'sex'] +\
    
    patients_to_change.loc[index,'possible_fracture_score'] = possible_fracture_score

patients_to_change.drop(columns=['age', 'weight', 'height', 'HIPX', 'HRT', 'smoking', 'ReumatoidArthritis', 'SecondaryOsteoporsis', 'Alcohol', 'VitaminD', 'calcium', 'dose_walk', 'dose_moderate', 'dose_vigorous', 'real_class', 'predicted_class'], inplace=True)

# %%
patients_to_change.sort_values('possible_fracture_score', ascending=False, inplace=True)

# %%
std_patients = pd.read_csv('../../../Data/women_menopause/standardized_patients.csv', index_col=0)
std_patients.drop(columns=['sex', 'menopause'],axis=1,inplace=True)
std_patients.shape
# Out:
# (153884, 15)

# %%
for i in range(1,6):
    new_std_patients = std_patients
    n_patients = int(patients_to_change.shape[0] * i * 10 / 100)
    patients_percentage = patients_to_change.head(n_patients)
    for index,element in patients_percentage.iterrows():
        new_std_patients.loc[index,'Class'] = 1
    new_std_patients.to_csv('../../../Data/women_menopause/starting_ratio_05/'+str(i)+'0_percent/new_std_patients.csv')

# %% [markdown]
# ## 7. Save the model

# %%
joblib.dump(mlp, nn_model_base_folder+neural_network_name+'_model.pkl')
conf_mat_df.to_csv(conf_mat_base_folder+neural_network_name+'.csv')
