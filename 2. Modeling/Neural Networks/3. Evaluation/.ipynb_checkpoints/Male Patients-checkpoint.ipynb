# %% [markdown]
# # <center><b><h1>Male Patients (Evaluation)</h1></b></center>

# %%
import itertools
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from math import cos, sin, atan
import numpy as np
from operator import itemgetter
import pandas as pd
from sklearn import datasets
from sklearn.externals import joblib
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, r2_score, recall_score, auc, roc_auc_score, roc_curve
from sklearn.metrics import classification_report,confusion_matrix, precision_score, f1_score
from sklearn.neural_network import MLPClassifier
from scipy.stats import spearmanr, pearsonr

# %% [markdown]
# ## 1. Load the data

# %% [markdown]
# ### 1.1 Validation and Test sets

# %%
df_X_test = pd.read_csv("../../../Data/male_patients/X_test.csv", index_col=0)
df_X_test.shape
# Out:
# (15836, 13)

# %%
df_y_test = pd.read_csv("../../../Data/male_patients/y_test.csv", index_col=0)
df_y_test.shape
# Out:
# (15836, 1)

# %%
df_X_val = pd.read_csv("../../../Data/male_patients/X_val.csv", index_col=0)
df_X_val.shape
# Out:
# (15836, 13)

# %%
df_y_val = pd.read_csv("../../../Data/male_patients/y_val.csv", index_col=0)
df_y_val.shape
# Out:
# (15836, 1)

# %% [markdown]
# ### 1.2 Neural Network models

# %%
model_folder_base = '../../../Models/Neural_Networks/male_patients/'

# %%
models = dict()

# %%
for base in ['05','1']:
    model_path = model_folder_base+'base_ratio_'+base+'/NeuralNetwork - Male_Patients - First Run - Base Ratio '+base+'_model.pkl'
    models.update({
        'base_ratio_'+base: {
            'model': joblib.load(model_path),
            'path' : model_path
        }
    })
    for percent in range(1,6):
        for ratio in ['05','1']:
            model_path = model_folder_base+'base_ratio_'+base+'/'+str(percent)+'0_percent/NeuralNetwork - Male_Patients - Second Run - '+str(percent)+'0 Percent - Ratio '+ratio+'_model.pkl'
                                                                                        #NeuralNetwork - Male_Patients - Second Run - 20 Percent - Ratio 1_model.pkl
            models.update({
                'base_ratio_'+base+'_'+str(percent)+'0_percent_ratio_'+ratio: {
                    'model': joblib.load(model_path),
                    'path' : model_path
                }
            })
len(models)#### Models trained with a Base Ratio of 1 between the classes
# Out:
# 22

# %% [markdown]
# ## 2. Models Comparison

# %% [markdown]
# ### 2.1 Computing the predictions and storing metrics

# %%
for key,element in models.items():
    path = element['path']
    model = element['model']
    predictions = model.predict(df_X_val.values)
    conf_mat = confusion_matrix(df_y_val['Class'].values,predictions)
    tp, fp, fn, tn = conf_mat.ravel()
    fpr, tpr, thresholds = roc_curve(df_y_val, predictions)
    models.update({
        key : {
            'model' : model,
            'path'  : path,
            'predictions' : predictions,
            'tp' : tp,
            'fp' : fp,
            'fn' : fn,
            'tn' : tn,            
            'recall' : tp/(tp+fn),
            'auc' : roc_auc_score(df_y_val, predictions),
            'f1-score' : f1_score(df_y_val,predictions),
            'precision' : tp / float(tp+fp),
            'fpr' : fpr,
            'tpr' : tpr,
            'thresholds' : thresholds,
        }
    })

# %%
len(models)
# Out:
# 22

# %% [markdown]
# ### 2.3 Resume table of models' metrics and features

# %%
models_df = pd.DataFrame(models).transpose()
models_df = models_df[['model','path','predictions','tp', 'fp', 'fn', 'tn', 'recall', 'auc', 'f1-score', 'precision', 'fpr', 'tpr', 'thresholds']]
models_df.drop(columns=['model','path','predictions'], axis=1, inplace=True)

# %%
models_df
# Out:
#                                       tp    fp  fn  tn    recall       auc  \
# base_ratio_05                      11018  4791  12  15  0.998912   0.62625
# base_ratio_05_10_percent_ratio_05  13041  2768   3  24   0.99977  0.856899
# base_ratio_05_10_percent_ratio_1   11572  4237   1  26  0.999914  0.847476
# base_ratio_05_20_percent_ratio_05  13160  2649   9  18  0.999317  0.749552
# base_ratio_05_20_percent_ratio_1   11594  4215   2  25  0.999828  0.829653
# base_ratio_05_30_percent_ratio_05  12959  2850  11  16  0.999152  0.706158
# base_ratio_05_30_percent_ratio_1   11633  4176   4  23  0.999656  0.793849
# base_ratio_05_40_percent_ratio_05  12825  2984  16  11  0.998754  0.609327
# base_ratio_05_40_percent_ratio_1   11839  3970  13  14  0.998903  0.633698
# base_ratio_05_50_percent_ratio_05  12821  2988  16  11  0.998754  0.609201
# base_ratio_05_50_percent_ratio_1   11391  4418  15  12  0.998685  0.582492
# base_ratio_1                       11187  4622  11  16  0.999018  0.650114
# base_ratio_1_10_percent_ratio_05   13108  2701   5  22  0.999619  0.821981
# base_ratio_1_10_percent_ratio_1    11863  3946   6  21  0.999494  0.764087
# base_ratio_1_20_percent_ratio_05   13514  2295   8  19  0.999408  0.779267
# base_ratio_1_20_percent_ratio_1    12352  3457   6  21  0.999514  0.779552
# base_ratio_1_30_percent_ratio_05   13564  2245  12  15  0.999116  0.706774
# base_ratio_1_30_percent_ratio_1    11842  3967   5  22  0.999578  0.781941
# base_ratio_1_40_percent_ratio_05   13395  2414  15  12  0.998881  0.645873
# base_ratio_1_40_percent_ratio_1    12091  3718  11  16  0.999091  0.678705
# base_ratio_1_50_percent_ratio_05   12903  2906  12  15  0.999071  0.685868
# base_ratio_1_50_percent_ratio_1    12173  3636  11  16  0.999097  0.681299
#
#                                      f1-score precision  \
# base_ratio_05                      0.00620732  0.696945
# base_ratio_05_10_percent_ratio_05   0.0170273   0.82491
# base_ratio_05_10_percent_ratio_1    0.0121212  0.731988
# base_ratio_05_20_percent_ratio_05    0.013363  0.832437
# base_ratio_05_20_percent_ratio_1    0.0117178   0.73338
# base_ratio_05_30_percent_ratio_05   0.0110612  0.819723
# base_ratio_05_30_percent_ratio_1     0.010885  0.735847
# base_ratio_05_40_percent_ratio_05  0.00727995  0.811247
# base_ratio_05_40_percent_ratio_1    0.0069808  0.748877
# base_ratio_05_50_percent_ratio_05  0.00727032  0.810994
# base_ratio_05_50_percent_ratio_1   0.00538479  0.720539
# base_ratio_1                       0.00685959  0.707635
# base_ratio_1_10_percent_ratio_05        0.016  0.829148
# base_ratio_1_10_percent_ratio_1     0.0105158  0.750395
# base_ratio_1_20_percent_ratio_05    0.0162324   0.85483
# base_ratio_1_20_percent_ratio_1     0.0119829  0.781327
# base_ratio_1_30_percent_ratio_05    0.0131176  0.857992
# base_ratio_1_30_percent_ratio_1     0.0109562  0.749067
# base_ratio_1_40_percent_ratio_05   0.00978394  0.847302
# base_ratio_1_40_percent_ratio_1    0.00850838  0.764818
# base_ratio_1_50_percent_ratio_05    0.0101764  0.816181
# base_ratio_1_50_percent_ratio_1    0.00869802  0.770004
#
#                                                                fpr  \
# base_ratio_05                        [0.0, 0.303055221709153, 1.0]
# base_ratio_05_10_percent_ratio_05  [0.0, 0.17509013852868618, 1.0]
# base_ratio_05_10_percent_ratio_1    [0.0, 0.2680118919602758, 1.0]
# base_ratio_05_20_percent_ratio_05  [0.0, 0.16756278069454109, 1.0]
# base_ratio_05_20_percent_ratio_1   [0.0, 0.26662027958757667, 1.0]
# base_ratio_05_30_percent_ratio_05   [0.0, 0.1802770573723828, 1.0]
# base_ratio_05_30_percent_ratio_1    [0.0, 0.2641533303814283, 1.0]
# base_ratio_05_40_percent_ratio_05   [0.0, 0.1887532418242773, 1.0]
# base_ratio_05_40_percent_ratio_1   [0.0, 0.25112277816433676, 1.0]
# base_ratio_05_50_percent_ratio_05  [0.0, 0.18900626225567715, 1.0]
# base_ratio_05_50_percent_ratio_1   [0.0, 0.27946106648111835, 1.0]
# base_ratio_1                       [0.0, 0.29236510848250996, 1.0]
# base_ratio_1_10_percent_ratio_05   [0.0, 0.17085204630273895, 1.0]
# base_ratio_1_10_percent_ratio_1    [0.0, 0.24960465557593775, 1.0]
# base_ratio_1_20_percent_ratio_05   [0.0, 0.14517047251565565, 1.0]
# base_ratio_1_20_percent_ratio_1    [0.0, 0.21867290783730786, 1.0]
# base_ratio_1_30_percent_ratio_05   [0.0, 0.14200771712315768, 1.0]
# base_ratio_1_30_percent_ratio_1     [0.0, 0.2509330128407869, 1.0]
# base_ratio_1_40_percent_ratio_05   [0.0, 0.15269783034980075, 1.0]
# base_ratio_1_40_percent_ratio_1    [0.0, 0.23518249098614713, 1.0]
# base_ratio_1_50_percent_ratio_05   [0.0, 0.18381934341198053, 1.0]
# base_ratio_1_50_percent_ratio_1     [0.0, 0.2299955721424505, 1.0]
#
#                                                               tpr thresholds
# base_ratio_05                      [0.0, 0.5555555555555556, 1.0]  [2, 1, 0]
# base_ratio_05_10_percent_ratio_05  [0.0, 0.8888888888888888, 1.0]  [2, 1, 0]
# base_ratio_05_10_percent_ratio_1   [0.0, 0.9629629629629629, 1.0]  [2, 1, 0]
# base_ratio_05_20_percent_ratio_05  [0.0, 0.6666666666666666, 1.0]  [2, 1, 0]
# base_ratio_05_20_percent_ratio_1   [0.0, 0.9259259259259259, 1.0]  [2, 1, 0]
# base_ratio_05_30_percent_ratio_05  [0.0, 0.5925925925925926, 1.0]  [2, 1, 0]
# base_ratio_05_30_percent_ratio_1   [0.0, 0.8518518518518519, 1.0]  [2, 1, 0]
# base_ratio_05_40_percent_ratio_05  [0.0, 0.4074074074074074, 1.0]  [2, 1, 0]
# base_ratio_05_40_percent_ratio_1   [0.0, 0.5185185185185185, 1.0]  [2, 1, 0]
# base_ratio_05_50_percent_ratio_05  [0.0, 0.4074074074074074, 1.0]  [2, 1, 0]
# base_ratio_05_50_percent_ratio_1   [0.0, 0.4444444444444444, 1.0]  [2, 1, 0]
# base_ratio_1                       [0.0, 0.5925925925925926, 1.0]  [2, 1, 0]
# base_ratio_1_10_percent_ratio_05   [0.0, 0.8148148148148148, 1.0]  [2, 1, 0]
# base_ratio_1_10_percent_ratio_1    [0.0, 0.7777777777777778, 1.0]  [2, 1, 0]
# base_ratio_1_20_percent_ratio_05   [0.0, 0.7037037037037037, 1.0]  [2, 1, 0]
# base_ratio_1_20_percent_ratio_1    [0.0, 0.7777777777777778, 1.0]  [2, 1, 0]
# base_ratio_1_30_percent_ratio_05   [0.0, 0.5555555555555556, 1.0]  [2, 1, 0]
# base_ratio_1_30_percent_ratio_1    [0.0, 0.8148148148148148, 1.0]  [2, 1, 0]
# base_ratio_1_40_percent_ratio_05   [0.0, 0.4444444444444444, 1.0]  [2, 1, 0]
# base_ratio_1_40_percent_ratio_1    [0.0, 0.5925925925925926, 1.0]  [2, 1, 0]
# base_ratio_1_50_percent_ratio_05   [0.0, 0.5555555555555556, 1.0]  [2, 1, 0]
# base_ratio_1_50_percent_ratio_1    [0.0, 0.5925925925925926, 1.0]  [2, 1, 0]

# %% [markdown]
# ### 2.4 ROC curves comparison

# %%
plt.figure(figsize=(18,12))
for name,model in models_df.iterrows():
    plt.plot(model.loc['fpr'], model.loc['tpr'], label=name+", auc="+str(model.loc['auc']))
    plt.legend(loc=4)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.rcParams['font.size'] = 11
    plt.title('ROC curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.grid(True)
    plt.savefig('Male_Patients_validation_roc.png')

# %% [markdown]
# ### 2.5 Best model selection

# %%
nn_models = sorted(models.values(), key=itemgetter('auc'), reverse=True)

# %%
best_nn_model = nn_models[0]['model']

# %%
for k,e in models.items():
    if e['path'] == nn_models[0]['path']:
        print('The Best Model is : ', k)
        break
# Out:
# The Best Model is :  base_ratio_05_10_percent_ratio_05

# %%
best_predictions = best_nn_model.predict(df_X_val.values)

# %% [markdown]
# ## 3. Best model testing and metrics visualization

# %% [markdown]
# ### 3.1 Classification Report

# %%
class_repo = classification_report(df_y_test['Class'].values,best_predictions,target_names=['Non-Fracture','Fracture'], output_dict=True)
class_repo = pd.DataFrame(class_repo).transpose()

# %%
class_repo
# Out:
#               f1-score  precision    recall  support
# Non-Fracture  0.902779   0.998773  0.823619  15818.0
# Fracture      0.001423   0.000716  0.111111     18.0
# micro avg     0.822809   0.822809  0.822809  15836.0
# macro avg     0.452101   0.499745  0.467365  15836.0
# weighted avg  0.901754   0.997639  0.822809  15836.0

# %% [markdown]
# ### 3.2 Confusion Matrix

# %%
conf_mat_base_folder = '../../../Data/confusion_matrix/neural_network/best_model_based/'

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
pred_test = best_nn_model.predict(df_X_test.values)

# %%
conf_mat = confusion_matrix(df_y_test['Class'].values,pred_test)
tn, fp, fn, tp = conf_mat.ravel()
fpr, tpr, thresholds = roc_curve(df_y_test['Class'].values,pred_test)

# %%
conf_mat_df = pd.DataFrame([list(pd.Series([tp, fp, fn, tn]))],columns=['tp', 'fp', 'fn', 'tn'])
conf_mat_df.columns.names = ['model']
conf_mat_df.rename(index={0: 'Male_Patients'},inplace=True)
conf_mat_df
# Out:
# model          tp    fp  fn     tn
# Male_Patients  12  2813   6  13005

# %%
np.set_printoptions(precision=2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"],
                      title='Confusion matrix')
plt.savefig(conf_mat_base_folder+'Male_Patients_Best_nn_model_testset_confusion_matrix.png', bbox_inches="tight")

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"], normalize=True,
                      title='Normalized confusion matrix')
plt.savefig(conf_mat_base_folder+'Male_Patients_Best_nn_model_testset_confusion_matrix_normalized.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix
# [[13005  2813]
#  [    6    12]]
# Normalized confusion matrix
# [[0.82 0.18]
#  [0.33 0.67]]

# %% [markdown]
# ### 3.3 ROC Curve and AUC

# %%
plt.plot(fpr,tpr, label = "AUC= "+str(roc_auc_score(df_y_test,pred_test)))
plt.legend(loc=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 11
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.savefig('Male_Patients_Best_ROC.png')

# %% [markdown]
# ### 3.4 Accuracy

# %%
accuracy = (tp + tn) / float(tp+tn+fp+fn)
print("Accuracy : ",accuracy)
# Out:
# Accuracy :  0.8219878757261935

# %% [markdown]
# ### 3.5 Recall (or Sensitivity)

# %%
recall = tp / (tp+fn)
print("Recall : ", recall)
recall_score(df_y_test, pred_test)
# Out:
# Recall :  0.6666666666666666
# 0.6666666666666666

# %% [markdown]
# ### 3.6 Classification Error

# %%
classification_error = (fp + fn) / float(tp+tn+fp+fn)
print("Error : ",classification_error)
# Out:
# Error :  0.17801212427380653

# %% [markdown]
# ### 3.7 Specificity

# %%
specificity = tn / (tn+fp)

print(specificity)
# Out:
# 0.8221646225818687

# %% [markdown]
# ### 3.8 False Positive Rate: When the actual value is negative, how often is the prediction incorrect?
#
# # CONTROLLARE

# %%
false_positive_rate = fp / float(tn+fp)

print(false_positive_rate)
#print(1 - specificity)
# Out:
# 0.17783537741813124

# %% [markdown]
# ### 4.7 Precision: When a positive value is predicted, how often is the prediction correct?

# %%
precision = tp / float(tp+fp)

print(precision)
# Out:
# 0.004247787610619469

# %% [markdown]
# ## 6. Neural Network Visualization

# %%
nn_model_base_folder = '../../../Models/Neural_Networks/best_models/'

# %%
class Neuron():
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def draw(self, neuron_radius):
        circle = plt.Circle((self.x, self.y), radius=neuron_radius, fill=False)
        plt.gca().add_patch(circle)


class Layer():
    def __init__(self, network, number_of_neurons, number_of_neurons_in_widest_layer):
        self.vertical_distance_between_layers = 6
        self.horizontal_distance_between_neurons = 2
        self.neuron_radius = 0.5
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.previous_layer = self.__get_previous_layer(network)
        self.y = self.__calculate_layer_y_position()
        self.neurons = self.__intialise_neurons(number_of_neurons)

    def __intialise_neurons(self, number_of_neurons):
        neurons = []
        x = self.__calculate_left_margin_so_layer_is_centered(number_of_neurons)
        for iteration in range(number_of_neurons):
            neuron = Neuron(x, self.y)
            neurons.append(neuron)
            x += self.horizontal_distance_between_neurons
        return neurons

    def __calculate_left_margin_so_layer_is_centered(self, number_of_neurons):
        return self.horizontal_distance_between_neurons * (self.number_of_neurons_in_widest_layer - number_of_neurons) / 2

    def __calculate_layer_y_position(self):
        if self.previous_layer:
            return self.previous_layer.y + self.vertical_distance_between_layers
        else:
            return 0

    def __get_previous_layer(self, network):
        if len(network.layers) > 0:
            return network.layers[-1]
        else:
            return None

    def __line_between_two_neurons(self, neuron1, neuron2):
        angle = atan((neuron2.x - neuron1.x) / float(neuron2.y - neuron1.y))
        x_adjustment = self.neuron_radius * sin(angle)
        y_adjustment = self.neuron_radius * cos(angle)
        line = plt.Line2D((neuron1.x - x_adjustment, neuron2.x + x_adjustment), (neuron1.y - y_adjustment, neuron2.y + y_adjustment))
        plt.gca().add_line(line)

    def draw(self, layerType=0):
        n_neurons = 0
        for neuron in self.neurons:
            neuron.draw( self.neuron_radius )
            n_neurons += 1
            if self.previous_layer:
                for previous_layer_neuron in self.previous_layer.neurons:
                    self.__line_between_two_neurons(neuron, previous_layer_neuron)
        # write Text
        x_text = self.number_of_neurons_in_widest_layer * self.horizontal_distance_between_neurons
        if layerType == 0:
            plt.text(x_text, self.y, 'Input Layer', fontsize = 12)
        elif layerType == -1:
            plt.text(x_text, self.y, 'Output Layer', fontsize = 12)
        else:
            plt.text(x_text, self.y, 'Hidden Layer '+str(layerType)+" - "+str(n_neurons)+" neurons", fontsize = 12)

class NeuralNetwork():
    def __init__(self, number_of_neurons_in_widest_layer):
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.layers = []
        self.layertype = 0

    def add_layer(self, number_of_neurons ):
        layer = Layer(self, number_of_neurons, self.number_of_neurons_in_widest_layer)
        self.layers.append(layer)

    def draw(self):
        plt.figure(figsize=(38,8), dpi=300)
        for i in range( len(self.layers) ):
            layer = self.layers[i]
            if i == len(self.layers)-1:
                i = -1
            layer.draw( i )
        plt.axis('scaled')
        plt.axis('off')
        plt.title( 'Neural Network architecture', fontsize=15 )
        plt.savefig(nn_model_base_folder+'Male_Patients_structure.png', bbox_inches="tight")
        plt.show()

class DrawNN():
    def __init__( self, neural_network ):
        self.neural_network = neural_network

    def draw( self ):
        widest_layer = max( self.neural_network )
        network = NeuralNetwork( widest_layer )
        for l in self.neural_network:
            network.add_layer(l)
        network.draw()

# %%
n_output = 1
nn_structure = []
nn_structure.append(df_X_test.shape[1])
for layer in best_nn_model.hidden_layer_sizes:
    nn_structure.append(layer)
nn_structure.append(n_output)

# %%
neural_network = DrawNN( nn_structure )
neural_network.draw()

# %% [markdown]
# ## 7. Save best model to file

# %%
joblib.dump(best_nn_model, nn_model_base_folder+'Male_Patients_Model.pkl')
conf_mat_df.to_csv(conf_mat_base_folder+'Male_Patients.csv')
