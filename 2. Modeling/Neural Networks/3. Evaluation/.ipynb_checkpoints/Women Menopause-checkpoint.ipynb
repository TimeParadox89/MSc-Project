# %% [markdown]
# # <center><b><h1>Female Patients in Menopause Condition (Evaluation)</h1></b></center>

# %%
import itertools
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from math import cos, sin, atan
import numpy as np
from operator import itemgetter
import pandas as pd
from sklearn import datasets
from sklearn.externals import joblib
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, r2_score, recall_score, auc, roc_auc_score, roc_curve
from sklearn.metrics import classification_report,confusion_matrix, precision_score, f1_score
from sklearn.neural_network import MLPClassifier
from scipy.stats import spearmanr, pearsonr

# %% [markdown]
# ## 1. Load the data

# %% [markdown]
# ### 1.1 Validation and Test sets

# %%
df_X_test = pd.read_csv("../../../Data/women_menopause/X_test.csv", index_col=0)
df_X_test.shape
# Out:
# (10043, 14)

# %%
df_y_test = pd.read_csv("../../../Data/women_menopause/y_test.csv", index_col=0)
df_y_test.shape
# Out:
# (10043, 1)

# %%
df_X_val = pd.read_csv("../../../Data/women_menopause/X_val.csv", index_col=0)
df_X_val.shape
# Out:
# (10043, 14)

# %%
df_y_val = pd.read_csv("../../../Data/women_menopause/y_val.csv", index_col=0)
df_y_val.shape
# Out:
# (10043, 1)

# %% [markdown]
# ### 1.2 Neural Network models

# %%
model_folder_base = '../../../Models/Neural_Networks/women_menopause/'

# %%
models = dict()

# %%
for base in ['05','1']:
    model_path = model_folder_base+'base_ratio_'+base+'/NeuralNetwork - Women_Menopause - First Run - Base Ratio '+base+'_model.pkl'
    models.update({
        'base_ratio_'+base: {
            'model': joblib.load(model_path),
            'path' : model_path
        }
    })
    for percent in range(1,6):
        for ratio in ['05','1']:
            model_path = model_folder_base+'base_ratio_'+base+'/'+str(percent)+'0_percent/NeuralNetwork - Women_Menopause - Second Run - '+str(percent)+'0 Percent - Ratio '+ratio+'_model.pkl'
            models.update({
                'base_ratio_'+base+'_'+str(percent)+'0_percent_ratio_'+ratio: {
                    'model': joblib.load(model_path),
                    'path' : model_path
                }
            })
len(models)#### Models trained with a Base Ratio of 1 between the classes
# Out:
# 22

# %%
#x = models['base_ratio_05_10_percent_ratio_1']['model']

# %% [markdown]
# ## 2. Models Comparison

# %% [markdown]
# ### 2.1 Computing the predictions and storing metrics

# %%
for key,element in models.items():
    path = element['path']
    model = element['model']
    predictions = model.predict(df_X_val.values)
    conf_mat = confusion_matrix(df_y_val['Class'].values,predictions)
    tp, fp, fn, tn = conf_mat.ravel()
    fpr, tpr, thresholds = roc_curve(df_y_val, predictions)
    models.update({
        key : {
            'model' : model,
            'path'  : path,
            'predictions' : predictions,
            'tp' : tp,
            'fp' : fp,
            'fn' : fn,
            'tn' : tn,            
            'recall' : tp/(tp+fn),
            'auc' : roc_auc_score(df_y_val, predictions),
            'f1-score' : f1_score(df_y_val,predictions),
            'precision' : tp / float(tp+fp),
            'fpr' : fpr,
            'tpr' : tpr,
            'thresholds' : thresholds,
        }
    })

# %%
len(models)
# Out:
# 22

# %% [markdown]
# ### 2.3 Resume table of models' metrics and features

# %%
models_df = pd.DataFrame(models).transpose()
models_df = models_df[['model','path','predictions','tp', 'fp', 'fn', 'tn', 'recall', 'auc', 'f1-score', 'precision', 'fpr', 'tpr', 'thresholds']]
models_df.drop(columns=['model','path','predictions'], axis=1, inplace=True)

# %%
models_df
# Out:
#                                      tp    fp  fn  tn    recall       auc  \
# base_ratio_05                      7055  2963  10  15  0.998585  0.652116
# base_ratio_05_10_percent_ratio_05  7424  2594   5  20  0.999327  0.770533
# base_ratio_05_10_percent_ratio_1   6037  3981   1  24  0.999834  0.781308
# base_ratio_05_20_percent_ratio_05  7851  2167   6  19  0.999236  0.771845
# base_ratio_05_20_percent_ratio_1   6749  3269   5  20   0.99926  0.736844
# base_ratio_05_30_percent_ratio_05  7462  2556   7  18  0.999063   0.73243
# base_ratio_05_30_percent_ratio_1   7035  2983  13  12  0.998156  0.591118
# base_ratio_05_40_percent_ratio_05  7499  2519   7  18  0.999067  0.734276
# base_ratio_05_40_percent_ratio_1   6902  3116   5  20  0.999276   0.74448
# base_ratio_05_50_percent_ratio_05  8147  1871  17   8  0.997918  0.566618
# base_ratio_05_50_percent_ratio_1   6943  3075   4  21  0.999424  0.766526
# base_ratio_1                       5910  4108  10  15  0.998311  0.594969
# base_ratio_1_10_percent_ratio_05   7719  2299   4  21  0.999482  0.805257
# base_ratio_1_10_percent_ratio_1    6810  3208   3  22   0.99956  0.779888
# base_ratio_1_20_percent_ratio_05   7454  2564   8  17  0.998928   0.71203
# base_ratio_1_20_percent_ratio_1    7071  2947  14  11  0.998024  0.572915
# base_ratio_1_30_percent_ratio_05   7714  2304  13  12  0.998318  0.625007
# base_ratio_1_30_percent_ratio_1    6414  3604   7  18   0.99891  0.680124
# base_ratio_1_40_percent_ratio_05   7365  2653  14  11  0.998103  0.587588
# base_ratio_1_40_percent_ratio_1    6483  3535  10  15   0.99846  0.623568
# base_ratio_1_50_percent_ratio_05   7077  2941  11  14  0.998448  0.633214
# base_ratio_1_50_percent_ratio_1    6048  3970   8  17  0.998679  0.641857
#
#                                      f1-score precision  \
# base_ratio_05                      0.00999001  0.704232
# base_ratio_05_10_percent_ratio_05   0.0151573  0.741066
# base_ratio_05_10_percent_ratio_1    0.0119107  0.602615
# base_ratio_05_20_percent_ratio_05   0.0171868  0.783689
# base_ratio_05_20_percent_ratio_1      0.01207  0.673687
# base_ratio_05_30_percent_ratio_05   0.0138515  0.744859
# base_ratio_05_30_percent_ratio_1   0.00794702  0.702236
# base_ratio_05_40_percent_ratio_05   0.0140515  0.748553
# base_ratio_05_40_percent_ratio_1    0.0126542   0.68896
# base_ratio_05_50_percent_ratio_05  0.00840336  0.813236
# base_ratio_05_50_percent_ratio_1    0.0134572  0.693053
# base_ratio_1                        0.0072324  0.589938
# base_ratio_1_10_percent_ratio_05    0.0179104  0.770513
# base_ratio_1_10_percent_ratio_1     0.0135177  0.679776
# base_ratio_1_20_percent_ratio_05    0.0130468  0.744061
# base_ratio_1_20_percent_ratio_1    0.00737513   0.70583
# base_ratio_1_30_percent_ratio_05     0.010252  0.770014
# base_ratio_1_30_percent_ratio_1    0.00987113  0.640248
# base_ratio_1_40_percent_ratio_05   0.00818148  0.735177
# base_ratio_1_40_percent_ratio_1    0.00839161  0.647135
# base_ratio_1_50_percent_ratio_05   0.00939597  0.706428
# base_ratio_1_50_percent_ratio_1    0.00847458  0.603713
#
#                                                                fpr  \
# base_ratio_05                      [0.0, 0.29576761828708326, 1.0]
# base_ratio_05_10_percent_ratio_05   [0.0, 0.2589339189458974, 1.0]
# base_ratio_05_10_percent_ratio_1    [0.0, 0.3973847075264524, 1.0]
# base_ratio_05_20_percent_ratio_05  [0.0, 0.21631064084647633, 1.0]
# base_ratio_05_20_percent_ratio_1    [0.0, 0.3263126372529447, 1.0]
# base_ratio_05_30_percent_ratio_05  [0.0, 0.25514074665601916, 1.0]
# base_ratio_05_30_percent_ratio_1    [0.0, 0.2977640247554402, 1.0]
# base_ratio_05_40_percent_ratio_05   [0.0, 0.2514473946895588, 1.0]
# base_ratio_05_40_percent_ratio_1     [0.0, 0.311040127770014, 1.0]
# base_ratio_05_50_percent_ratio_05  [0.0, 0.18676382511479336, 1.0]
# base_ratio_05_50_percent_ratio_1   [0.0, 0.30694749450988223, 1.0]
# base_ratio_1                       [0.0, 0.41006188860051906, 1.0]
# base_ratio_1_10_percent_ratio_05   [0.0, 0.22948692353763225, 1.0]
# base_ratio_1_10_percent_ratio_1      [0.0, 0.320223597524456, 1.0]
# base_ratio_1_20_percent_ratio_05   [0.0, 0.25593930924336195, 1.0]
# base_ratio_1_20_percent_ratio_1     [0.0, 0.2941704931123977, 1.0]
# base_ratio_1_30_percent_ratio_05    [0.0, 0.2299860251547215, 1.0]
# base_ratio_1_30_percent_ratio_1    [0.0, 0.35975244559792374, 1.0]
# base_ratio_1_40_percent_ratio_05   [0.0, 0.26482331802755044, 1.0]
# base_ratio_1_40_percent_ratio_1     [0.0, 0.3528648432820922, 1.0]
# base_ratio_1_50_percent_ratio_05    [0.0, 0.2935715711718906, 1.0]
# base_ratio_1_50_percent_ratio_1     [0.0, 0.3962866839688561, 1.0]
#
#                                                 tpr thresholds
# base_ratio_05                       [0.0, 0.6, 1.0]  [2, 1, 0]
# base_ratio_05_10_percent_ratio_05   [0.0, 0.8, 1.0]  [2, 1, 0]
# base_ratio_05_10_percent_ratio_1   [0.0, 0.96, 1.0]  [2, 1, 0]
# base_ratio_05_20_percent_ratio_05  [0.0, 0.76, 1.0]  [2, 1, 0]
# base_ratio_05_20_percent_ratio_1    [0.0, 0.8, 1.0]  [2, 1, 0]
# base_ratio_05_30_percent_ratio_05  [0.0, 0.72, 1.0]  [2, 1, 0]
# base_ratio_05_30_percent_ratio_1   [0.0, 0.48, 1.0]  [2, 1, 0]
# base_ratio_05_40_percent_ratio_05  [0.0, 0.72, 1.0]  [2, 1, 0]
# base_ratio_05_40_percent_ratio_1    [0.0, 0.8, 1.0]  [2, 1, 0]
# base_ratio_05_50_percent_ratio_05  [0.0, 0.32, 1.0]  [2, 1, 0]
# base_ratio_05_50_percent_ratio_1   [0.0, 0.84, 1.0]  [2, 1, 0]
# base_ratio_1                        [0.0, 0.6, 1.0]  [2, 1, 0]
# base_ratio_1_10_percent_ratio_05   [0.0, 0.84, 1.0]  [2, 1, 0]
# base_ratio_1_10_percent_ratio_1    [0.0, 0.88, 1.0]  [2, 1, 0]
# base_ratio_1_20_percent_ratio_05   [0.0, 0.68, 1.0]  [2, 1, 0]
# base_ratio_1_20_percent_ratio_1    [0.0, 0.44, 1.0]  [2, 1, 0]
# base_ratio_1_30_percent_ratio_05   [0.0, 0.48, 1.0]  [2, 1, 0]
# base_ratio_1_30_percent_ratio_1    [0.0, 0.72, 1.0]  [2, 1, 0]
# base_ratio_1_40_percent_ratio_05   [0.0, 0.44, 1.0]  [2, 1, 0]
# base_ratio_1_40_percent_ratio_1     [0.0, 0.6, 1.0]  [2, 1, 0]
# base_ratio_1_50_percent_ratio_05   [0.0, 0.56, 1.0]  [2, 1, 0]
# base_ratio_1_50_percent_ratio_1    [0.0, 0.68, 1.0]  [2, 1, 0]

# %% [markdown]
# ### 2.4 ROC curves comparison

# %%
plt.figure(figsize=(18,12))
for name,model in models_df.iterrows():
    plt.plot(model.loc['fpr'], model.loc['tpr'], label=name+", auc="+str(model.loc['auc']))
    plt.legend(loc=4)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.rcParams['font.size'] = 11
    plt.title('ROC curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.grid(True)
    plt.savefig('Women_Menopause_validation_roc.png')

# %% [markdown]
# ### 2.5 Best model selection

# %%
nn_models = sorted(models.values(), key=itemgetter('auc'), reverse=True)

# %%
best_nn_model = nn_models[0]['model']

# %%
for k,e in models.items():
    if e['path'] == nn_models[0]['path']:
        print('The Best Model is : ', k)
        break
# Out:
# The Best Model is :  base_ratio_1_10_percent_ratio_05

# %%
best_predictions = best_nn_model.predict(df_X_val.values)

# %% [markdown]
# ## 3. Best model testing and metrics visualization

# %% [markdown]
# ### 3.1 Classification Report

# %%
class_repo = classification_report(df_y_test['Class'].values,best_predictions,target_names=['Non-Fracture','Fracture'], output_dict=True)
class_repo = pd.DataFrame(class_repo).transpose()

# %%
class_repo
# Out:
#               f1-score  precision    recall  support
# Non-Fracture  0.868054   0.996245  0.769092  10004.0
# Fracture      0.008478   0.004310  0.256410     39.0
# micro avg     0.767101   0.767101  0.767101  10043.0
# macro avg     0.438266   0.500278  0.512751  10043.0
# weighted avg  0.864716   0.992393  0.767101  10043.0

# %% [markdown]
# ### 3.2 Confusion Matrix

# %%
conf_mat_base_folder = '../../../Data/confusion_matrix/neural_network/best_model_based/'

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
pred_test = best_nn_model.predict(df_X_test.values)

# %%
conf_mat = confusion_matrix(df_y_test['Class'].values,pred_test)
tn, fp, fn, tp = conf_mat.ravel()
fpr, tpr, thresholds = roc_curve(df_y_test['Class'].values,pred_test)

# %%
conf_mat_df = pd.DataFrame([list(pd.Series([tp, fp, fn, tn]))],columns=['tp', 'fp', 'fn', 'tn'])
conf_mat_df.columns.names = ['model']
conf_mat_df.rename(index={0: 'Women_Menopause'},inplace=True)
conf_mat_df
# Out:
# model            tp    fp  fn    tn
# Women_Menopause  24  2248  15  7756

# %%
np.set_printoptions(precision=2)

# Plot confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"],
                      title='Confusion matrix')
plt.savefig(conf_mat_base_folder+'Women_Menopause_Best_nn_model_testset_confusion_matrix.png', bbox_inches="tight")

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(conf_mat, classes=['Non-Fracture', "Fracture"], normalize=True,
                      title='Normalized confusion matrix')
plt.savefig(conf_mat_base_folder+'Women_Menopause_Best_nn_model_testset_confusion_matrix_normalized.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix
# [[7756 2248]
#  [  15   24]]
# Normalized confusion matrix
# [[0.78 0.22]
#  [0.38 0.62]]

# %% [markdown]
# ### 3.3 ROC Curve and AUC

# %%
plt.plot(fpr,tpr, label = "AUC= "+str(roc_auc_score(df_y_test,pred_test)))
plt.legend(loc=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 11
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.savefig('Women_Menopause_Best_ROC.png')

# %% [markdown]
# ### 3.4 Accuracy

# %%
accuracy = (tp + tn) / float(tp+tn+fp+fn)
print("Accuracy : ",accuracy)
# Out:
# Accuracy :  0.7746689236283979

# %% [markdown]
# ### 3.5 Recall (or Sensitivity)

# %%
recall = tp / (tp+fn)
print("Recall : ", recall)
recall_score(df_y_test, pred_test)
# Out:
# Recall :  0.6153846153846154
# 0.6153846153846154

# %% [markdown]
# ### 3.6 Classification Error

# %%
classification_error = (fp + fn) / float(tp+tn+fp+fn)
print("Error : ",classification_error)
# Out:
# Error :  0.2253310763716021

# %% [markdown]
# ### 3.7 Specificity

# %%
specificity = tn / (tn+fp)

print(specificity)
# Out:
# 0.7752898840463814

# %% [markdown]
# ### 3.8 False Positive Rate: When the actual value is negative, how often is the prediction incorrect?
#
# # CONTROLLARE

# %%
false_positive_rate = fp / float(tn+fp)

print(false_positive_rate)
#print(1 - specificity)
# Out:
# 0.22471011595361856

# %% [markdown]
# ### 4.7 Precision: When a positive value is predicted, how often is the prediction correct?

# %%
precision = tp / float(tp+fp)

print(precision)
# Out:
# 0.01056338028169014

# %% [markdown]
# ## 6. Neural Network Visualization

# %%
nn_model_base_folder = '../../../Models/Neural_Networks/best_models/'

# %%
class Neuron():
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def draw(self, neuron_radius):
        circle = plt.Circle((self.x, self.y), radius=neuron_radius, fill=False)
        plt.gca().add_patch(circle)


class Layer():
    def __init__(self, network, number_of_neurons, number_of_neurons_in_widest_layer):
        self.vertical_distance_between_layers = 6
        self.horizontal_distance_between_neurons = 2
        self.neuron_radius = 0.5
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.previous_layer = self.__get_previous_layer(network)
        self.y = self.__calculate_layer_y_position()
        self.neurons = self.__intialise_neurons(number_of_neurons)

    def __intialise_neurons(self, number_of_neurons):
        neurons = []
        x = self.__calculate_left_margin_so_layer_is_centered(number_of_neurons)
        for iteration in range(number_of_neurons):
            neuron = Neuron(x, self.y)
            neurons.append(neuron)
            x += self.horizontal_distance_between_neurons
        return neurons

    def __calculate_left_margin_so_layer_is_centered(self, number_of_neurons):
        return self.horizontal_distance_between_neurons * (self.number_of_neurons_in_widest_layer - number_of_neurons) / 2

    def __calculate_layer_y_position(self):
        if self.previous_layer:
            return self.previous_layer.y + self.vertical_distance_between_layers
        else:
            return 0

    def __get_previous_layer(self, network):
        if len(network.layers) > 0:
            return network.layers[-1]
        else:
            return None

    def __line_between_two_neurons(self, neuron1, neuron2):
        angle = atan((neuron2.x - neuron1.x) / float(neuron2.y - neuron1.y))
        x_adjustment = self.neuron_radius * sin(angle)
        y_adjustment = self.neuron_radius * cos(angle)
        line = plt.Line2D((neuron1.x - x_adjustment, neuron2.x + x_adjustment), (neuron1.y - y_adjustment, neuron2.y + y_adjustment))
        plt.gca().add_line(line)

    def draw(self, layerType=0):
        n_neurons = 0
        for neuron in self.neurons:
            neuron.draw( self.neuron_radius )
            n_neurons += 1
            if self.previous_layer:
                for previous_layer_neuron in self.previous_layer.neurons:
                    self.__line_between_two_neurons(neuron, previous_layer_neuron)
        # write Text
        x_text = self.number_of_neurons_in_widest_layer * self.horizontal_distance_between_neurons
        if layerType == 0:
            plt.text(x_text, self.y, 'Input Layer', fontsize = 12)
        elif layerType == -1:
            plt.text(x_text, self.y, 'Output Layer', fontsize = 12)
        else:
            plt.text(x_text, self.y, 'Hidden Layer '+str(layerType)+" - "+str(n_neurons)+" neurons", fontsize = 12)

class NeuralNetwork():
    def __init__(self, number_of_neurons_in_widest_layer):
        self.number_of_neurons_in_widest_layer = number_of_neurons_in_widest_layer
        self.layers = []
        self.layertype = 0

    def add_layer(self, number_of_neurons ):
        layer = Layer(self, number_of_neurons, self.number_of_neurons_in_widest_layer)
        self.layers.append(layer)

    def draw(self):
        plt.figure(figsize=(38,8), dpi=300)
        for i in range( len(self.layers) ):
            layer = self.layers[i]
            if i == len(self.layers)-1:
                i = -1
            layer.draw( i )
        plt.axis('scaled')
        plt.axis('off')
        plt.title( 'Neural Network architecture', fontsize=15 )
        plt.savefig(nn_model_base_folder+'Women_Menopause_structure.png', bbox_inches="tight")
        plt.show()

class DrawNN():
    def __init__( self, neural_network ):
        self.neural_network = neural_network

    def draw( self ):
        widest_layer = max( self.neural_network )
        network = NeuralNetwork( widest_layer )
        for l in self.neural_network:
            network.add_layer(l)
        network.draw()

# %%
n_output = 1
nn_structure = []
nn_structure.append(df_X_test.shape[1])
for layer in best_nn_model.hidden_layer_sizes:
    nn_structure.append(layer)
nn_structure.append(n_output)

# %%
neural_network = DrawNN( nn_structure )
neural_network.draw()

# %% [markdown]
# ## 7. Save best model to file

# %%
joblib.dump(best_nn_model, nn_model_base_folder+'Women_Menopause_Model.pkl')
conf_mat_df.to_csv(conf_mat_base_folder+'Women_Menopause.csv')
