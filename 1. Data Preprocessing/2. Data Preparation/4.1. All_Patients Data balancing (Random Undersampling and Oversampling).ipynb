# %% [markdown]
# # Data Balancing - Undersampling class 0 and oversampling class 1

# %%
from collections import Counter
from imblearn.over_sampling import ADASYN
from imblearn.under_sampling import RandomUnderSampler
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Load the Data

# %%
starting_ratio = '1'
percent_ratio = '10_percent/'#''
base_data_folder = '../../Data/all_patients/starting_ratio_'+starting_ratio+'/'+percent_ratio

# %%
X_train = pd.read_csv(base_data_folder+'X_train_total.csv', index_col=0, header=0)
y_train = pd.read_csv(base_data_folder+'y_train_total.csv', index_col=0, header=0)
X_train.shape, y_train.shape
# Out:
# ((92330, 16), (92330, 1))

# %% [markdown]
# ## 2. Undersampling

# %%
ratio = 0.5

# %%
y_train[y_train['Class'] == 1].shape
# Out:
# (525, 1)

# %%
rus = RandomUnderSampler(sampling_strategy=ratio, random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train, y_train['Class'].values)
print('Resampled dataset shape %s' % Counter(y_resampled))
# Out:
# Resampled dataset shape Counter({0: 525, 1: 525})

# %%
X_resampled.shape
# Out:
# (1050, 16)

# %%
y_resampled.shape
# Out:
# (1050,)

# %% [markdown]
# ## 3. Oversampling

# %%
adasyn = ADASYN(random_state=42, sampling_strategy=ratio)
X_resampled_total, y_resampled_total = adasyn.fit_resample(X_resampled, y_resampled)
print('Resampled dataset shape %s' % Counter(y_resampled_total))
# Out:
# Resampled dataset shape Counter({0: 525, 1: 525})

# %%
total_patients = pd.DataFrame(X_resampled_total)
total_patients["Class"] = y_resampled_total

# %% [markdown]
# ## 4. Dataset merge and Data preparation for disk writing

# %%
total_patients = pd.DataFrame(X_resampled_total)
total_patients["Class"] = y_resampled_total

# %%
columns_names = ['sex', 'age', 'weight', 'height', 'HIPX', 'menopause', 'HRT', 'smoking',
       'ReumatoidArthritis', 'SecondaryOsteoporsis', 'Alcohol', 'VitaminD',
       'calcium', 'dose_walk', 'dose_moderate', 'dose_vigorous','Class']

# %%
total_patients.columns = columns_names

# %%
total_patients = total_patients.sample(frac=1).reset_index(drop=True)

# %%
X_train_resampled = total_patients.iloc[:,:total_patients.shape[1]-1]
X_train_resampled
# Out:
#            sex       age    weight    height       HIPX  menopause       HRT  \
# 0    -1.029482 -0.343985 -0.120857 -1.166701  -0.037838   1.436838  2.362657
# 1     0.971362 -1.088910 -0.369506  0.737192  -0.037838  -0.695973 -0.423252
# 2    -1.029482  0.649249 -0.949686 -0.785922  -0.037838   1.436838  2.362657
# 3     0.971362 -0.964756  0.331812  0.954780  -0.037838  -0.695973 -0.423252
# 4     0.971362  0.773403  0.707973  0.954780  -0.037838  -0.695973 -0.423252
# 5    -1.029482  0.400940 -1.612750 -1.547479  -0.037838   1.436838 -0.423252
# 6    -1.029482  0.773403 -0.382257  0.084429  -0.037838   1.436838  2.362657
# 7    -1.029482  0.152632 -0.847677 -0.568335  -0.037838   1.436838 -0.423252
# 8     0.971362 -0.592293  0.472076 -0.133159  -0.037838  -0.695973 -0.423252
# 9     0.971362 -0.840602  0.338188  1.063574  -0.037838  -0.695973 -0.423252
# 10   -1.029482 -1.461373 -1.083574 -0.785922  -0.037838  -0.695973 -0.423252
# 11   -1.029482  0.773403 -1.364101 -1.982655  -0.037838   1.436838  2.362657
# 12    0.971362 -0.219831  1.734447  0.845986  -0.037838  -0.695973 -0.423252
# 13    0.971362  1.145866 -0.630906  0.519604  -0.037838  -0.695973 -0.423252
# 14    0.971362  0.400940  0.803607  1.281161  -0.037838  -0.695973 -0.423252
# 15   -1.029482 -1.088910 -1.651004 -0.568335  -0.037838  -0.695973 -0.423252
# 16    0.971362 -0.219831 -0.190988  0.410810  -0.037838  -0.695973 -0.423252
# 17   -1.029482 -1.709681 -0.586276 -0.677128  -0.037838  -0.695973 -0.423252
# 18    0.971362  0.152632 -0.069852  0.519604  -0.037838  -0.695973 -0.423252
# 19   -1.029482  1.642483 -1.797643 -1.438686  -0.037838   1.436838  2.362657
# 20    0.971362  1.145866 -0.395008 -0.133159  -0.037838  -0.695973 -0.423252
# 21   -1.029482 -0.840602 -0.133608  0.084429  -0.037838   1.436838 -0.423252
# 22   -1.029482  1.642483  0.950247 -0.894716  -0.037838   1.436838 -0.423252
# 23   -1.029482 -0.219831 -0.803047 -0.894716  -0.037838   1.436838  2.362657
# 24   -1.029482 -0.964756 -1.389604 -1.275495  -0.037838  -0.695973 -0.423252
# 25   -1.029482 -0.840602 -0.841301 -1.003510  -0.037838  -0.695973 -0.423252
# 26   -1.029482  1.021712  0.911993 -0.350747  -0.037838   1.436838 -0.423252
# 27    0.971362  1.021712 -0.356754  0.302016  -0.037838  -0.695973 -0.423252
# 28   -1.029482 -1.461373 -0.618154 -0.785922  -0.037838  -0.695973 -0.423252
# 29    0.971362  0.400940  0.102290 -0.785922  -0.037838  -0.695973 -0.423252
# ...        ...       ...       ...       ...        ...        ...       ...
# 1020 -1.029482  0.649249 -0.006096  0.302016  -0.037838   1.436838  2.362657
# 1021 -1.029482 -0.592293  0.344563  0.084429  -0.037838  -0.695973 -0.423252
# 1022  0.971362 -0.840602  1.932091  0.954780  -0.037838  -0.695973 -0.423252
# 1023 -1.029482  0.773403 -1.364101 -1.873861  -0.037838   1.436838 -0.423252
# 1024  0.971362  0.897557  0.325436  0.954780  -0.037838  -0.695973 -0.423252
# 1025  0.971362  0.276786 -0.108105  0.193223  -0.037838  -0.695973 -0.423252
# 1026  0.971362  1.270020  2.518648  1.063574  -0.037838  -0.695973 -0.423252
# 1027  0.971362 -0.343985  0.478451  0.084429  -0.037838  -0.695973 -0.423252
# 1028  0.971362  0.525095  1.262652  1.607543  -0.037838  -0.695973 -0.423252
# 1029  0.971362 -1.088910 -0.382257  0.628398  -0.037838  -0.695973 -0.423252
# 1030 -1.029482  0.773403 -1.198335 -1.656273  -0.037838   1.436838  2.362657
# 1031  0.971362  0.400940  0.185173  2.260306  -0.037838  -0.695973 -0.423252
# 1032 -1.029482  1.270020 -0.241993 -1.221098  -0.037838   1.436838  2.362657
# 1033 -1.029482  0.400940 -1.791267 -1.982655  -0.037838   1.436838 -0.423252
# 1034 -1.029482 -0.592293 -0.630906 -0.568335  -0.037838   1.436838 -0.423252
# 1035 -1.029482  0.897557 -1.370477 -0.785922  -0.037838   1.436838  2.362657
# 1036  0.971362  1.021712  0.044909  0.410810  -0.037838  -0.695973 -0.423252
# 1037 -1.029482  0.773403 -1.619126 -1.003510  -0.037838   1.436838 -0.423252
# 1038 -1.029482  1.518328  0.465700 -0.785922  -0.037838   1.436838  2.362657
# 1039  0.971362  1.518328  1.084134  1.063574  -0.037838  -0.695973 -0.423252
# 1040 -1.029482  1.145866 -1.402355 -1.547479  -0.037838   1.436838  2.362657
# 1041 -1.029482  0.649249 -0.241993 -0.024365  -0.037838   1.436838 -0.423252
# 1042 -1.029482  1.642483 -1.313096 -0.894716  -0.037838   1.436838 -0.423252
# 1043  0.971362 -0.840602  1.409291  0.519604  -0.037838  -0.695973 -0.423252
# 1044  0.971362  0.649249 -0.082603  0.519604  26.428635  -0.695973 -0.423252
# 1045  0.971362 -1.461373  1.575057  2.260306  -0.037838  -0.695973 -0.423252
# 1046  0.971362 -0.343985 -0.854052 -0.241953  26.428635  -0.695973 -0.423252
# 1047 -1.029482  0.525095  0.765354  0.410810  -0.037838   1.436838 -0.423252
# 1048  0.971362  0.773403  0.121417  1.172367  -0.037838  -0.695973 -0.423252
# 1049 -1.029482  0.773403 -1.485238 -1.438686  -0.037838   1.436838  2.362657
#
#        smoking  ReumatoidArthritis  SecondaryOsteoporsis   Alcohol  VitaminD  \
# 0     0.760768           -0.088950              7.450683 -0.788571 -0.355935
# 1     2.330176           -0.088950             -0.134216 -0.168304 -0.537271
# 2     0.760768           -0.088950             -0.134216 -0.239257 -0.044036
# 3     0.760768           -0.088950             -0.134216 -0.206756 -0.714981
# 4    -0.808640           -0.088950             -0.134216  0.430906 -0.359561
# 5     0.760768           -0.088950             -0.134216  0.645138 -0.758502
# 6     0.760768           -0.088950             -0.134216 -0.237884 -0.442976
# 7    -0.808640           -0.088950              7.450683 -0.788571 -0.551778
# 8    -0.808640           -0.088950             -0.134216 -0.788571  2.142881
# 9    -0.808640           -0.088950             -0.134216 -0.431059 -0.450230
# 10   -0.808640           -0.088950             -0.134216 -0.788571  0.543494
# 11    0.760768           11.242216             -0.134216 -0.084534 -0.852796
# 12    0.760768           -0.088950             -0.134216  0.874019  0.434692
# 13   -0.808640           -0.088950             -0.134216  0.647427 -0.486497
# 14    2.330176           -0.088950             -0.134216 -0.788571 -0.555405
# 15   -0.808640           -0.088950             -0.134216 -0.788571 -0.983359
# 16    2.330176           -0.088950             -0.134216 -0.788571  0.173568
# 17   -0.808640           -0.088950             -0.134216 -0.788571 -0.820156
# 18   -0.808640           -0.088950             -0.134216  0.235441  1.326867
# 19    0.760768           11.242216             -0.134216 -0.788571  2.552701
# 20   -0.808640           -0.088950             -0.134216 -0.788571 -0.754875
# 21   -0.808640           -0.088950             -0.134216 -0.788571 -0.555405
# 22    0.760768           -0.088950             -0.134216 -0.143127 -0.646073
# 23   -0.808640           -0.088950              7.450683 -0.788571  1.758448
# 24    0.760768           -0.088950             -0.134216  0.834651  0.840886
# 25   -0.808640           -0.088950             -0.134216 -0.422362 -0.475617
# 26    0.760768           11.242216             -0.134216 -0.788571 -0.918078
# 27    0.760768           -0.088950             -0.134216  0.104979  0.449199
# 28   -0.808640           -0.088950             -0.134216 -0.664518 -0.863677
# 29    0.760768           -0.088950             -0.134216 -0.788571 -0.228999
# ...        ...                 ...                   ...       ...       ...
# 1020 -0.808640           -0.088950              7.450683  2.019338 -0.707727
# 1021 -0.808640           11.242216             -0.134216 -0.788571 -0.501004
# 1022  0.760768           11.242216             -0.134216 -0.788571  1.754821
# 1023 -0.808640           11.242216             -0.134216 -0.084534 -0.493750
# 1024 -0.808640           -0.088950             -0.134216 -0.788571 -0.867303
# 1025 -0.808640           -0.088950             -0.134216  0.112304  0.438319
# 1026 -0.808640           -0.088950             -0.134216  2.347553 -0.555405
# 1027  2.330176           -0.088950              7.450683  3.291458 -0.094810
# 1028  0.760768           -0.088950             -0.134216  0.998072 -0.740368
# 1029 -0.808640           -0.088950             -0.134216 -0.019532 -0.613432
# 1030 -0.808640           -0.088950              7.450683  0.338896 -0.305160
# 1031 -0.808640           -0.088950             -0.134216 -0.356444 -0.602552
# 1032  0.760768           -0.088950              7.450683 -0.788571 -0.450230
# 1033 -0.808640           11.242216             -0.134216 -0.181579  1.693167
# 1034  2.330176           -0.088950             -0.134216 -0.788571 -0.508257
# 1035 -0.808640           -0.088950              7.450683 -0.513914  0.750217
# 1036 -0.808640           11.242216             -0.134216 -0.787656  0.804618
# 1037  0.760768           11.242216             -0.134216 -0.788571 -0.232626
# 1038 -0.808640           -0.088950             -0.134216 -0.788571 -0.791142
# 1039 -0.808640           -0.088950             -0.134216 -0.239257 -0.054916
# 1040  2.330176           -0.088950             -0.134216 -0.572508 -0.642446
# 1041  2.330176           -0.088950             -0.134216  0.464780  0.771978
# 1042 -0.808640           -0.088950             -0.134216 -0.572508 -0.363188
# 1043  2.330176           -0.088950             -0.134216 -0.726316 -0.667833
# 1044  2.330176           -0.088950             -0.134216  1.891623 -0.849170
# 1045  2.330176           -0.088950             -0.134216 -0.788571 -0.845543
# 1046  2.330176           -0.088950             -0.134216  1.088709 -0.348681
# 1047  2.330176           -0.088950             -0.134216 -0.788571 -0.399455
# 1048  0.760768           -0.088950             -0.134216  1.467278  1.736687
# 1049  0.760768           -0.088950             -0.134216 -0.788571 -0.932584
#
#        calcium  dose_walk  dose_moderate  dose_vigorous
# 0    -1.300353   0.208233      -0.611945      -0.538945
# 1     0.088455  -0.415141       0.135155       1.312374
# 2    -0.559472   0.208233      -0.487428       0.571847
# 3    -0.396517  -0.493062      -0.088975       0.849545
# 4    -0.220138   0.208233       0.135155       0.942110
# 5    -1.125845   1.143293       2.525877      -0.292102
# 6    -0.907502  -0.025532       0.433996      -0.477234
# 7     1.076777  -0.660037       2.525877       0.078161
# 8    -0.730415   3.280573      -0.313105       0.386715
# 9    -0.373209   0.208233      -0.611945       0.571847
# 10    0.310540  -0.548721      -0.562138      -0.538945
# 11    3.322072  -0.493062      -0.487428      -0.538945
# 12    1.486364  -0.448536       0.010639      -0.538945
# 13   -0.460779  -0.025532      -0.611945      -0.538945
# 14   -0.357358  -0.192507      -0.014265       0.942110
# 15   -0.455773  -0.548721      -0.562138      -0.477234
# 16    0.357535   0.608973       0.135155       1.312374
# 17    0.286852  -0.415141      -0.537235      -0.538945
# 18    1.254015  -0.392877      -0.611945      -0.415524
# 19    1.001797  -0.025532       0.135155      -0.538945
# 20   -0.490306  -0.682301       0.956966       0.756979
# 21    3.247218  -0.025532       0.433996       0.571847
# 22   -0.736230  -0.259297      -0.462525      -0.538945
# 23   -0.070632  -0.025532      -0.163685      -0.538945
# 24   -0.237076   0.052389       1.181096       0.201583
# 25   -1.187048  -0.726827      -0.611945      -0.538945
# 26   -0.736634  -0.103454      -0.163685      -0.538945
# 27    1.573984  -0.192507       0.583416       1.682638
# 28    0.219481   0.341813      -0.163685      -0.261247
# 29   -1.120006  -0.504194       2.525877       0.571847
# ...        ...        ...            ...            ...
# 1020 -1.279877  -0.504194      -0.387815      -0.261247
# 1021  0.760777  -0.526457      -0.275750      -0.353813
# 1022  0.687616  -0.671169      -0.462525      -0.538945
# 1023  0.587760  -0.459667      -0.313105       0.201583
# 1024 -0.125768  -0.448536      -0.562138       0.109017
# 1025 -0.527644  -0.504194      -0.462525       0.201583
# 1026 -0.644843  -0.392877      -0.313105      -0.168681
# 1027 -0.542105  -0.548721      -0.611945      -0.415524
# 1028  0.441364  -0.058927      -0.462525      -0.261247
# 1029 -0.366788  -0.459667      -0.313105      -0.477234
# 1030 -0.401093   0.208233       0.284575       0.571847
# 1031 -0.014131   0.208233      -0.163685      -0.261247
# 1032 -0.958239   2.078353       2.874524       0.109017
# 1033  0.612080   0.208233      -0.088975      -0.538945
# 1034 -0.673207   4.883533       1.479936       0.386715
# 1035 -0.593423   0.675763      -0.300653       0.078161
# 1036  0.987412  -0.326087      -0.462525      -0.477234
# 1037 -0.149101  -0.615511      -0.362912      -0.415524
# 1038 -1.359079  -0.566531      -0.512332      -0.538945
# 1039  0.247946  -0.259297      -0.350460      -0.261247
# 1040  0.760094  -0.559852      -0.562138      -0.538945
# 1041 -0.093359  -0.459667      -0.313105      -0.168681
# 1042  0.301666  -0.459667      -0.462525       2.423166
# 1043  0.965343   0.208233      -0.238395       0.386715
# 1044  2.812023   0.519919      -0.387815      -0.353813
# 1045 -0.208029  -0.548721      -0.163685       0.571847
# 1046 -0.415123   1.143293       2.525877       0.386715
# 1047 -0.326871   1.143293      -0.462525      -0.538945
# 1048  0.468110  -0.660037      -0.432641      -0.464892
# 1049 -0.554492  -0.192507      -0.537235      -0.538945
#
# [1050 rows x 16 columns]

# %%
y_train_resampled = pd.DataFrame(total_patients['Class'], columns=['Class'])
y_train_resampled
# Out:
#       Class
# 0         1
# 1         1
# 2         0
# 3         0
# 4         0
# 5         1
# 6         1
# 7         1
# 8         0
# 9         0
# 10        0
# 11        1
# 12        0
# 13        0
# 14        1
# 15        0
# 16        1
# 17        0
# 18        0
# 19        1
# 20        0
# 21        1
# 22        0
# 23        1
# 24        0
# 25        0
# 26        1
# 27        1
# 28        0
# 29        0
# ...     ...
# 1020      1
# 1021      1
# 1022      1
# 1023      1
# 1024      0
# 1025      0
# 1026      0
# 1027      1
# 1028      0
# 1029      0
# 1030      1
# 1031      0
# 1032      1
# 1033      1
# 1034      0
# 1035      1
# 1036      1
# 1037      1
# 1038      0
# 1039      1
# 1040      1
# 1041      0
# 1042      0
# 1043      1
# 1044      1
# 1045      1
# 1046      1
# 1047      1
# 1048      1
# 1049      0
#
# [1050 rows x 1 columns]

# %% [markdown]
# ## 5. Save to file

# %%
if ratio < 1 :
    ratio_folder = 'ratio_05/'
else:
    ratio_folder = 'ratio_1/'
total_patients.to_csv(base_data_folder+ratio_folder+'total_patients_trainset_balanced.csv')
X_train_resampled.to_csv(base_data_folder+ratio_folder+'X_train.csv')
y_train_resampled.to_csv(base_data_folder+ratio_folder+'y_train.csv')

# %%
'''
for i in range (1,6):
    starting_ratio = '1'
    percent_ratio = str(i)+'0'
    base_data_folder = '../../Data/all_patients/starting_ratio_'+starting_ratio+'/'+percent_ratio+'_percent/'
    
    X_train = pd.read_csv(base_data_folder+'X_train_total.csv', index_col=0, header=0)
    y_train = pd.read_csv(base_data_folder+'y_train_total.csv', index_col=0, header=0)
    X_train.shape, y_train.shape
    
    for i in [0.5,1]:
        
        ratio = i

        rus = RandomUnderSampler(sampling_strategy=ratio, random_state=42)
        X_resampled, y_resampled = rus.fit_resample(X_train, y_train['Class'].values)

        adasyn = ADASYN(random_state=42, sampling_strategy=ratio)
        X_resampled_total, y_resampled_total = adasyn.fit_resample(X_resampled, y_resampled)

        total_patients = pd.DataFrame(X_resampled_total)
        total_patients["Class"] = y_resampled_total

        columns_names = ['sex', 'age', 'weight', 'height', 'HIPX', 'menopause', 'HRT', 'smoking',
           'ReumatoidArthritis', 'SecondaryOsteoporsis', 'Alcohol', 'VitaminD',
           'calcium', 'dose_walk', 'dose_moderate', 'dose_vigorous','Class']
        total_patients.columns = columns_names
        total_patients = total_patients.sample(frac=1).reset_index(drop=True)

        X_train_resampled = total_patients.iloc[:,:total_patients.shape[1]-1]

        y_train_resampled = pd.DataFrame(total_patients['Class'], columns=['Class'])

        if ratio < 1:
            ratio_folder = 'ratio_05/'
        else:
            ratio_folder = 'ratio_1/'
        total_patients.to_csv(base_data_folder+ratio_folder+'total_patients_trainset_balanced.csv')
        X_train_resampled.to_csv(base_data_folder+ratio_folder+'X_train.csv')
        y_train_resampled.to_csv(base_data_folder+ratio_folder+'y_train.csv')
'''
