# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
import numpy as np
from sklearn.decomposition import PCA
from numpy.random import rand

# %%
patients = pd.read_csv('../Data/standardized_patients.csv', index_col=0)
patients.shape
# Out:
# (153884, 17)

# %%
females = patients[patients['sex'] < 0]
females.drop(columns=['menopause','HRT'], axis=1, inplace=True)
# Out:
# /Users/erennio/.local/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
females.shape
# Out:
# (74707, 15)

# %%
y = females['Class'].values

# %%
tsne = TSNE(n_components=2, random_state=0, verbose=1).fit_transform(females)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 74707 samples in 9.870s...
# [t-SNE] Computed neighbors for 74707 samples in 188.911s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 74707
# [t-SNE] Computed conditional probabilities for sample 2000 / 74707
# [t-SNE] Computed conditional probabilities for sample 3000 / 74707
# [t-SNE] Computed conditional probabilities for sample 4000 / 74707
# [t-SNE] Computed conditional probabilities for sample 5000 / 74707
# [t-SNE] Computed conditional probabilities for sample 6000 / 74707
# [t-SNE] Computed conditional probabilities for sample 7000 / 74707
# [t-SNE] Computed conditional probabilities for sample 8000 / 74707
# [t-SNE] Computed conditional probabilities for sample 9000 / 74707
# [t-SNE] Computed conditional probabilities for sample 10000 / 74707
# [t-SNE] Computed conditional probabilities for sample 11000 / 74707
# [t-SNE] Computed conditional probabilities for sample 12000 / 74707
# [t-SNE] Computed conditional probabilities for sample 13000 / 74707
# [t-SNE] Computed conditional probabilities for sample 14000 / 74707
# [t-SNE] Computed conditional probabilities for sample 15000 / 74707
# [t-SNE] Computed conditional probabilities for sample 16000 / 74707
# [t-SNE] Computed conditional probabilities for sample 17000 / 74707
# [t-SNE] Computed conditional probabilities for sample 18000 / 74707
# [t-SNE] Computed conditional probabilities for sample 19000 / 74707
# [t-SNE] Computed conditional probabilities for sample 20000 / 74707
# [t-SNE] Computed conditional probabilities for sample 21000 / 74707
# [t-SNE] Computed conditional probabilities for sample 22000 / 74707
# [t-SNE] Computed conditional probabilities for sample 23000 / 74707
# [t-SNE] Computed conditional probabilities for sample 24000 / 74707
# [t-SNE] Computed conditional probabilities for sample 25000 / 74707
# [t-SNE] Computed conditional probabilities for sample 26000 / 74707
# [t-SNE] Computed conditional probabilities for sample 27000 / 74707
# [t-SNE] Computed conditional probabilities for sample 28000 / 74707
# [t-SNE] Computed conditional probabilities for sample 29000 / 74707
# [t-SNE] Computed conditional probabilities for sample 30000 / 74707
# [t-SNE] Computed conditional probabilities for sample 31000 / 74707
# [t-SNE] Computed conditional probabilities for sample 32000 / 74707
# [t-SNE] Computed conditional probabilities for sample 33000 / 74707
# [t-SNE] Computed conditional probabilities for sample 34000 / 74707
# [t-SNE] Computed conditional probabilities for sample 35000 / 74707
# [t-SNE] Computed conditional probabilities for sample 36000 / 74707
# [t-SNE] Computed conditional probabilities for sample 37000 / 74707
# [t-SNE] Computed conditional probabilities for sample 38000 / 74707
# [t-SNE] Computed conditional probabilities for sample 39000 / 74707
# [t-SNE] Computed conditional probabilities for sample 40000 / 74707
# [t-SNE] Computed conditional probabilities for sample 41000 / 74707
# [t-SNE] Computed conditional probabilities for sample 42000 / 74707
# [t-SNE] Computed conditional probabilities for sample 43000 / 74707
# [t-SNE] Computed conditional probabilities for sample 44000 / 74707
# [t-SNE] Computed conditional probabilities for sample 45000 / 74707
# [t-SNE] Computed conditional probabilities for sample 46000 / 74707
# [t-SNE] Computed conditional probabilities for sample 47000 / 74707
# [t-SNE] Computed conditional probabilities for sample 48000 / 74707
# [t-SNE] Computed conditional probabilities for sample 49000 / 74707
# [t-SNE] Computed conditional probabilities for sample 50000 / 74707
# [t-SNE] Computed conditional probabilities for sample 51000 / 74707
# [t-SNE] Computed conditional probabilities for sample 52000 / 74707
# [t-SNE] Computed conditional probabilities for sample 53000 / 74707
# [t-SNE] Computed conditional probabilities for sample 54000 / 74707
# [t-SNE] Computed conditional probabilities for sample 55000 / 74707
# [t-SNE] Computed conditional probabilities for sample 56000 / 74707
# [t-SNE] Computed conditional probabilities for sample 57000 / 74707
# [t-SNE] Computed conditional probabilities for sample 58000 / 74707
# [t-SNE] Computed conditional probabilities for sample 59000 / 74707
# [t-SNE] Computed conditional probabilities for sample 60000 / 74707
# [t-SNE] Computed conditional probabilities for sample 61000 / 74707
# [t-SNE] Computed conditional probabilities for sample 62000 / 74707
# [t-SNE] Computed conditional probabilities for sample 63000 / 74707
# [t-SNE] Computed conditional probabilities for sample 64000 / 74707
# [t-SNE] Computed conditional probabilities for sample 65000 / 74707
# [t-SNE] Computed conditional probabilities for sample 66000 / 74707
# [t-SNE] Computed conditional probabilities for sample 67000 / 74707
# [t-SNE] Computed conditional probabilities for sample 68000 / 74707
# [t-SNE] Computed conditional probabilities for sample 69000 / 74707
# [t-SNE] Computed conditional probabilities for sample 70000 / 74707
# [t-SNE] Computed conditional probabilities for sample 71000 / 74707
# [t-SNE] Computed conditional probabilities for sample 72000 / 74707
# [t-SNE] Computed conditional probabilities for sample 73000 / 74707
# [t-SNE] Computed conditional probabilities for sample 74000 / 74707
# [t-SNE] Computed conditional probabilities for sample 74707 / 74707
# [t-SNE] Mean sigma: 0.410253
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 104.242104
# [t-SNE] KL divergence after 1000 iterations: 3.652346

# %%
tsne
# Out:
# array([[-30.160706 , -25.75296  ],
#        [ 10.2047615, -37.88951  ],
#        [ 11.583481 ,  17.38076  ],
#        ...,
#        [ 23.243692 , -10.307597 ],
#        [ 43.88762  , -20.524542 ],
#        [ 38.646187 , -26.762758 ]], dtype=float32)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(*zip(*tsne), c=y, cmap='PiYG_r', marker='+')
plt.show()
