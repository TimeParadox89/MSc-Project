# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
import numpy as np
from sklearn.decomposition import PCA
from numpy.random import rand
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

# %%
patients = pd.read_csv('../Data/standardized_patients.csv', index_col=0)
patients.shape
# Out:
# (153884, 17)

# %%
females = patients[patients['sex'] < 0]

# %%
females = females[females['menopause'] < 0]
females.drop(columns=["menopause", "HRT"], axis=1, inplace=True)

# %%
females.shape
# Out:
# (24492, 15)

# %%
#rus = RandomUnderSampler(sampling_strategy=0.2, random_state=42)
#X_resampled, y_resampled = rus.fit_resample(females.iloc[:,:females.shape[1]-1], females['Class'].values)
#print('Resampled dataset shape %s' % Counter(y_resampled))

# %%
y = females['Class'].values

# %%
#y = y_resampled

# %%
tsne = TSNE(n_components=2, random_state=0, verbose=1).fit_transform(females)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 24492 samples in 0.566s...
# [t-SNE] Computed neighbors for 24492 samples in 13.426s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 24492
# [t-SNE] Computed conditional probabilities for sample 2000 / 24492
# [t-SNE] Computed conditional probabilities for sample 3000 / 24492
# [t-SNE] Computed conditional probabilities for sample 4000 / 24492
# [t-SNE] Computed conditional probabilities for sample 5000 / 24492
# [t-SNE] Computed conditional probabilities for sample 6000 / 24492
# [t-SNE] Computed conditional probabilities for sample 7000 / 24492
# [t-SNE] Computed conditional probabilities for sample 8000 / 24492
# [t-SNE] Computed conditional probabilities for sample 9000 / 24492
# [t-SNE] Computed conditional probabilities for sample 10000 / 24492
# [t-SNE] Computed conditional probabilities for sample 11000 / 24492
# [t-SNE] Computed conditional probabilities for sample 12000 / 24492
# [t-SNE] Computed conditional probabilities for sample 13000 / 24492
# [t-SNE] Computed conditional probabilities for sample 14000 / 24492
# [t-SNE] Computed conditional probabilities for sample 15000 / 24492
# [t-SNE] Computed conditional probabilities for sample 16000 / 24492
# [t-SNE] Computed conditional probabilities for sample 17000 / 24492
# [t-SNE] Computed conditional probabilities for sample 18000 / 24492
# [t-SNE] Computed conditional probabilities for sample 19000 / 24492
# [t-SNE] Computed conditional probabilities for sample 20000 / 24492
# [t-SNE] Computed conditional probabilities for sample 21000 / 24492
# [t-SNE] Computed conditional probabilities for sample 22000 / 24492
# [t-SNE] Computed conditional probabilities for sample 23000 / 24492
# [t-SNE] Computed conditional probabilities for sample 24000 / 24492
# [t-SNE] Computed conditional probabilities for sample 24492 / 24492
# [t-SNE] Mean sigma: 0.434736
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.957283
# [t-SNE] KL divergence after 1000 iterations: 2.736262

# %%
tsne
# Out:
# array([[-19.79741  ,  18.865114 ],
#        [  4.851302 , -63.706768 ],
#        [-49.47379  ,  34.657093 ],
#        ...,
#        [-26.61969  , -39.17336  ],
#        [ 51.3304   , -48.01029  ],
#        [  5.4987273, -62.830406 ]], dtype=float32)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(*zip(*tsne), c=y, cmap='PiYG_r', marker='+')
plt.show()
