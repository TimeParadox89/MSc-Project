# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
import numpy as np
from sklearn.decomposition import PCA
from numpy.random import rand
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

# %%
patients = pd.read_csv('../Data/standardized_patients.csv', index_col=0)
patients.shape
# Out:
# (153884, 17)

# %%
females = patients[patients['sex'] < 0]

# %%
females = females[females['menopause'] > 0]
females.drop(columns=["menopause"],axis=1,inplace=True)

# %%
females.shape
# Out:
# (50215, 16)

# %%
#rus = RandomUnderSampler(sampling_strategy=0.2, random_state=42)
#X_resampled, y_resampled = rus.fit_resample(females.iloc[:,:females.shape[1]-1], females['Class'].values)
#print('Resampled dataset shape %s' % Counter(y_resampled))

# %%
y = females['Class'].values

# %%
#y = y_resampled

# %%
tsne = TSNE(n_components=2, random_state=0, verbose=1).fit_transform(females.iloc[:,:females.shape[1]-1])
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 50215 samples in 3.267s...
# [t-SNE] Computed neighbors for 50215 samples in 79.414s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 50215
# [t-SNE] Computed conditional probabilities for sample 2000 / 50215
# [t-SNE] Computed conditional probabilities for sample 3000 / 50215
# [t-SNE] Computed conditional probabilities for sample 4000 / 50215
# [t-SNE] Computed conditional probabilities for sample 5000 / 50215
# [t-SNE] Computed conditional probabilities for sample 6000 / 50215
# [t-SNE] Computed conditional probabilities for sample 7000 / 50215
# [t-SNE] Computed conditional probabilities for sample 8000 / 50215
# [t-SNE] Computed conditional probabilities for sample 9000 / 50215
# [t-SNE] Computed conditional probabilities for sample 10000 / 50215
# [t-SNE] Computed conditional probabilities for sample 11000 / 50215
# [t-SNE] Computed conditional probabilities for sample 12000 / 50215
# [t-SNE] Computed conditional probabilities for sample 13000 / 50215
# [t-SNE] Computed conditional probabilities for sample 14000 / 50215
# [t-SNE] Computed conditional probabilities for sample 15000 / 50215
# [t-SNE] Computed conditional probabilities for sample 16000 / 50215
# [t-SNE] Computed conditional probabilities for sample 17000 / 50215
# [t-SNE] Computed conditional probabilities for sample 18000 / 50215
# [t-SNE] Computed conditional probabilities for sample 19000 / 50215
# [t-SNE] Computed conditional probabilities for sample 20000 / 50215
# [t-SNE] Computed conditional probabilities for sample 21000 / 50215
# [t-SNE] Computed conditional probabilities for sample 22000 / 50215
# [t-SNE] Computed conditional probabilities for sample 23000 / 50215
# [t-SNE] Computed conditional probabilities for sample 24000 / 50215
# [t-SNE] Computed conditional probabilities for sample 25000 / 50215
# [t-SNE] Computed conditional probabilities for sample 26000 / 50215
# [t-SNE] Computed conditional probabilities for sample 27000 / 50215
# [t-SNE] Computed conditional probabilities for sample 28000 / 50215
# [t-SNE] Computed conditional probabilities for sample 29000 / 50215
# [t-SNE] Computed conditional probabilities for sample 30000 / 50215
# [t-SNE] Computed conditional probabilities for sample 31000 / 50215
# [t-SNE] Computed conditional probabilities for sample 32000 / 50215
# [t-SNE] Computed conditional probabilities for sample 33000 / 50215
# [t-SNE] Computed conditional probabilities for sample 34000 / 50215
# [t-SNE] Computed conditional probabilities for sample 35000 / 50215
# [t-SNE] Computed conditional probabilities for sample 36000 / 50215
# [t-SNE] Computed conditional probabilities for sample 37000 / 50215
# [t-SNE] Computed conditional probabilities for sample 38000 / 50215
# [t-SNE] Computed conditional probabilities for sample 39000 / 50215
# [t-SNE] Computed conditional probabilities for sample 40000 / 50215
# [t-SNE] Computed conditional probabilities for sample 41000 / 50215
# [t-SNE] Computed conditional probabilities for sample 42000 / 50215
# [t-SNE] Computed conditional probabilities for sample 43000 / 50215
# [t-SNE] Computed conditional probabilities for sample 44000 / 50215
# [t-SNE] Computed conditional probabilities for sample 45000 / 50215
# [t-SNE] Computed conditional probabilities for sample 46000 / 50215
# [t-SNE] Computed conditional probabilities for sample 47000 / 50215
# [t-SNE] Computed conditional probabilities for sample 48000 / 50215
# [t-SNE] Computed conditional probabilities for sample 49000 / 50215
# [t-SNE] Computed conditional probabilities for sample 50000 / 50215
# [t-SNE] Computed conditional probabilities for sample 50215 / 50215
# [t-SNE] Mean sigma: 0.457053
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 96.137794
# [t-SNE] KL divergence after 1000 iterations: 3.070168

# %%
tsne
# Out:
# array([[ -5.282196, -23.282553],
#        [-41.14289 , -10.262601],
#        [ 38.59598 , -11.809392],
#        ...,
#        [-21.577173,  -7.001689],
#        [ -3.38364 ,  -2.628541],
#        [-31.267397,  18.890106]], dtype=float32)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(*zip(*tsne), c=y, cmap='PiYG_r', marker='+')
plt.show()
