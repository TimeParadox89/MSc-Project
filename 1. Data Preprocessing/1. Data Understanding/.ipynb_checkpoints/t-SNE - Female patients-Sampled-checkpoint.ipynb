# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
import numpy as np
from sklearn.decomposition import PCA
from numpy.random import rand
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

# %%
patients = pd.read_csv('../Data/standardized_patients.csv', index_col=0)
patients.shape
# Out:
# (153884, 17)

# %%
females = patients[patients['sex'] < 0]
females.drop(columns=['menopause','HRT'], axis=1, inplace=True)
# Out:
# /Users/erennio/.local/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
females.shape
# Out:
# (74707, 15)

# %%
rus = RandomUnderSampler(sampling_strategy=0.2, random_state=42)
X_resampled, y_resampled = rus.fit_resample(females.iloc[:,:females.shape[1]-1], females['Class'].values)
print('Resampled dataset shape %s' % Counter(y_resampled))
# Out:
# Resampled dataset shape Counter({0: 770, 1: 154})

# %%
y = y_resampled

# %%
tsne = TSNE(n_components=2, random_state=0, verbose=1).fit_transform(X_resampled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 924 samples in 0.001s...
# [t-SNE] Computed neighbors for 924 samples in 0.034s...
# [t-SNE] Computed conditional probabilities for sample 924 / 924
# [t-SNE] Mean sigma: 0.900484
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.924149
# [t-SNE] KL divergence after 1000 iterations: 1.129721

# %%
tsne
# Out:
# array([[ -8.304742 ,   4.276848 ],
#        [-10.547379 , -10.650814 ],
#        [ 21.460926 ,   1.578276 ],
#        ...,
#        [ 41.203682 ,  15.316005 ],
#        [  3.8370814,   7.2565093],
#        [  7.038342 , -46.720844 ]], dtype=float32)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(*zip(*tsne), c=y, cmap='PiYG_r', marker='+')
plt.show()
