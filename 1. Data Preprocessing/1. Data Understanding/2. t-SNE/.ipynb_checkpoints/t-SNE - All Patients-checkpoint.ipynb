# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
import numpy as np
from sklearn.decomposition import PCA
from numpy.random import rand

# %%
patients = pd.read_csv('../../../Data/standardized_patients.csv', index_col=0)
patients.shape
# Out:
# (153884, 17)

# %%
y = patients['Class'].values

# %%
tsne = TSNE(n_components=2, random_state=0, verbose=1).fit_transform(patients)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 153884 samples in 17.284s...
# [t-SNE] Computed neighbors for 153884 samples in 1319.847s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 153884
# [t-SNE] Computed conditional probabilities for sample 2000 / 153884
# [t-SNE] Computed conditional probabilities for sample 3000 / 153884
# [t-SNE] Computed conditional probabilities for sample 4000 / 153884
# [t-SNE] Computed conditional probabilities for sample 5000 / 153884
# [t-SNE] Computed conditional probabilities for sample 6000 / 153884
# [t-SNE] Computed conditional probabilities for sample 7000 / 153884
# [t-SNE] Computed conditional probabilities for sample 8000 / 153884
# [t-SNE] Computed conditional probabilities for sample 9000 / 153884
# [t-SNE] Computed conditional probabilities for sample 10000 / 153884
# [t-SNE] Computed conditional probabilities for sample 11000 / 153884
# [t-SNE] Computed conditional probabilities for sample 12000 / 153884
# [t-SNE] Computed conditional probabilities for sample 13000 / 153884
# [t-SNE] Computed conditional probabilities for sample 14000 / 153884
# [t-SNE] Computed conditional probabilities for sample 15000 / 153884
# [t-SNE] Computed conditional probabilities for sample 16000 / 153884
# [t-SNE] Computed conditional probabilities for sample 17000 / 153884
# [t-SNE] Computed conditional probabilities for sample 18000 / 153884
# [t-SNE] Computed conditional probabilities for sample 19000 / 153884
# [t-SNE] Computed conditional probabilities for sample 20000 / 153884
# [t-SNE] Computed conditional probabilities for sample 21000 / 153884
# [t-SNE] Computed conditional probabilities for sample 22000 / 153884
# [t-SNE] Computed conditional probabilities for sample 23000 / 153884
# [t-SNE] Computed conditional probabilities for sample 24000 / 153884
# [t-SNE] Computed conditional probabilities for sample 25000 / 153884
# [t-SNE] Computed conditional probabilities for sample 26000 / 153884
# [t-SNE] Computed conditional probabilities for sample 27000 / 153884
# [t-SNE] Computed conditional probabilities for sample 28000 / 153884
# [t-SNE] Computed conditional probabilities for sample 29000 / 153884
# [t-SNE] Computed conditional probabilities for sample 30000 / 153884
# [t-SNE] Computed conditional probabilities for sample 31000 / 153884
# [t-SNE] Computed conditional probabilities for sample 32000 / 153884
# [t-SNE] Computed conditional probabilities for sample 33000 / 153884
# [t-SNE] Computed conditional probabilities for sample 34000 / 153884
# [t-SNE] Computed conditional probabilities for sample 35000 / 153884
# [t-SNE] Computed conditional probabilities for sample 36000 / 153884
# [t-SNE] Computed conditional probabilities for sample 37000 / 153884
# [t-SNE] Computed conditional probabilities for sample 38000 / 153884
# [t-SNE] Computed conditional probabilities for sample 39000 / 153884
# [t-SNE] Computed conditional probabilities for sample 40000 / 153884
# [t-SNE] Computed conditional probabilities for sample 41000 / 153884
# [t-SNE] Computed conditional probabilities for sample 42000 / 153884
# [t-SNE] Computed conditional probabilities for sample 43000 / 153884
# [t-SNE] Computed conditional probabilities for sample 44000 / 153884
# [t-SNE] Computed conditional probabilities for sample 45000 / 153884
# [t-SNE] Computed conditional probabilities for sample 46000 / 153884
# [t-SNE] Computed conditional probabilities for sample 47000 / 153884
# [t-SNE] Computed conditional probabilities for sample 48000 / 153884
# [t-SNE] Computed conditional probabilities for sample 49000 / 153884
# [t-SNE] Computed conditional probabilities for sample 50000 / 153884
# [t-SNE] Computed conditional probabilities for sample 51000 / 153884
# [t-SNE] Computed conditional probabilities for sample 52000 / 153884
# [t-SNE] Computed conditional probabilities for sample 53000 / 153884
# [t-SNE] Computed conditional probabilities for sample 54000 / 153884
# [t-SNE] Computed conditional probabilities for sample 55000 / 153884
# [t-SNE] Computed conditional probabilities for sample 56000 / 153884
# [t-SNE] Computed conditional probabilities for sample 57000 / 153884
# [t-SNE] Computed conditional probabilities for sample 58000 / 153884
# [t-SNE] Computed conditional probabilities for sample 59000 / 153884
# [t-SNE] Computed conditional probabilities for sample 60000 / 153884
# [t-SNE] Computed conditional probabilities for sample 61000 / 153884
# [t-SNE] Computed conditional probabilities for sample 62000 / 153884
# [t-SNE] Computed conditional probabilities for sample 63000 / 153884
# [t-SNE] Computed conditional probabilities for sample 64000 / 153884
# [t-SNE] Computed conditional probabilities for sample 65000 / 153884
# [t-SNE] Computed conditional probabilities for sample 66000 / 153884
# [t-SNE] Computed conditional probabilities for sample 67000 / 153884
# [t-SNE] Computed conditional probabilities for sample 68000 / 153884
# [t-SNE] Computed conditional probabilities for sample 69000 / 153884
# [t-SNE] Computed conditional probabilities for sample 70000 / 153884
# [t-SNE] Computed conditional probabilities for sample 71000 / 153884
# [t-SNE] Computed conditional probabilities for sample 72000 / 153884
# [t-SNE] Computed conditional probabilities for sample 73000 / 153884
# [t-SNE] Computed conditional probabilities for sample 74000 / 153884
# [t-SNE] Computed conditional probabilities for sample 75000 / 153884
# [t-SNE] Computed conditional probabilities for sample 76000 / 153884
# [t-SNE] Computed conditional probabilities for sample 77000 / 153884
# [t-SNE] Computed conditional probabilities for sample 78000 / 153884
# [t-SNE] Computed conditional probabilities for sample 79000 / 153884
# [t-SNE] Computed conditional probabilities for sample 80000 / 153884
# [t-SNE] Computed conditional probabilities for sample 81000 / 153884
# [t-SNE] Computed conditional probabilities for sample 82000 / 153884
# [t-SNE] Computed conditional probabilities for sample 83000 / 153884
# [t-SNE] Computed conditional probabilities for sample 84000 / 153884
# [t-SNE] Computed conditional probabilities for sample 85000 / 153884
# [t-SNE] Computed conditional probabilities for sample 86000 / 153884
# [t-SNE] Computed conditional probabilities for sample 87000 / 153884
# [t-SNE] Computed conditional probabilities for sample 88000 / 153884
# [t-SNE] Computed conditional probabilities for sample 89000 / 153884
# [t-SNE] Computed conditional probabilities for sample 90000 / 153884
# [t-SNE] Computed conditional probabilities for sample 91000 / 153884
# [t-SNE] Computed conditional probabilities for sample 92000 / 153884
# [t-SNE] Computed conditional probabilities for sample 93000 / 153884
# [t-SNE] Computed conditional probabilities for sample 94000 / 153884
# [t-SNE] Computed conditional probabilities for sample 95000 / 153884
# [t-SNE] Computed conditional probabilities for sample 96000 / 153884
# [t-SNE] Computed conditional probabilities for sample 97000 / 153884
# [t-SNE] Computed conditional probabilities for sample 98000 / 153884
# [t-SNE] Computed conditional probabilities for sample 99000 / 153884
# [t-SNE] Computed conditional probabilities for sample 100000 / 153884
# [t-SNE] Computed conditional probabilities for sample 101000 / 153884
# [t-SNE] Computed conditional probabilities for sample 102000 / 153884
# [t-SNE] Computed conditional probabilities for sample 103000 / 153884
# [t-SNE] Computed conditional probabilities for sample 104000 / 153884
# [t-SNE] Computed conditional probabilities for sample 105000 / 153884
# [t-SNE] Computed conditional probabilities for sample 106000 / 153884
# [t-SNE] Computed conditional probabilities for sample 107000 / 153884
# [t-SNE] Computed conditional probabilities for sample 108000 / 153884
# [t-SNE] Computed conditional probabilities for sample 109000 / 153884
# [t-SNE] Computed conditional probabilities for sample 110000 / 153884
# [t-SNE] Computed conditional probabilities for sample 111000 / 153884
# [t-SNE] Computed conditional probabilities for sample 112000 / 153884
# [t-SNE] Computed conditional probabilities for sample 113000 / 153884
# [t-SNE] Computed conditional probabilities for sample 114000 / 153884
# [t-SNE] Computed conditional probabilities for sample 115000 / 153884
# [t-SNE] Computed conditional probabilities for sample 116000 / 153884
# [t-SNE] Computed conditional probabilities for sample 117000 / 153884
# [t-SNE] Computed conditional probabilities for sample 118000 / 153884
# [t-SNE] Computed conditional probabilities for sample 119000 / 153884
# [t-SNE] Computed conditional probabilities for sample 120000 / 153884
# [t-SNE] Computed conditional probabilities for sample 121000 / 153884
# [t-SNE] Computed conditional probabilities for sample 122000 / 153884
# [t-SNE] Computed conditional probabilities for sample 123000 / 153884
# [t-SNE] Computed conditional probabilities for sample 124000 / 153884
# [t-SNE] Computed conditional probabilities for sample 125000 / 153884
# [t-SNE] Computed conditional probabilities for sample 126000 / 153884
# [t-SNE] Computed conditional probabilities for sample 127000 / 153884
# [t-SNE] Computed conditional probabilities for sample 128000 / 153884
# [t-SNE] Computed conditional probabilities for sample 129000 / 153884
# [t-SNE] Computed conditional probabilities for sample 130000 / 153884
# [t-SNE] Computed conditional probabilities for sample 131000 / 153884
# [t-SNE] Computed conditional probabilities for sample 132000 / 153884
# [t-SNE] Computed conditional probabilities for sample 133000 / 153884
# [t-SNE] Computed conditional probabilities for sample 134000 / 153884
# [t-SNE] Computed conditional probabilities for sample 135000 / 153884
# [t-SNE] Computed conditional probabilities for sample 136000 / 153884
# [t-SNE] Computed conditional probabilities for sample 137000 / 153884
# [t-SNE] Computed conditional probabilities for sample 138000 / 153884
# [t-SNE] Computed conditional probabilities for sample 139000 / 153884
# [t-SNE] Computed conditional probabilities for sample 140000 / 153884
# [t-SNE] Computed conditional probabilities for sample 141000 / 153884
# [t-SNE] Computed conditional probabilities for sample 142000 / 153884
# [t-SNE] Computed conditional probabilities for sample 143000 / 153884
# [t-SNE] Computed conditional probabilities for sample 144000 / 153884
# [t-SNE] Computed conditional probabilities for sample 145000 / 153884
# [t-SNE] Computed conditional probabilities for sample 146000 / 153884
# [t-SNE] Computed conditional probabilities for sample 147000 / 153884
# [t-SNE] Computed conditional probabilities for sample 148000 / 153884
# [t-SNE] Computed conditional probabilities for sample 149000 / 153884
# [t-SNE] Computed conditional probabilities for sample 150000 / 153884
# [t-SNE] Computed conditional probabilities for sample 151000 / 153884
# [t-SNE] Computed conditional probabilities for sample 152000 / 153884
# [t-SNE] Computed conditional probabilities for sample 153000 / 153884
# [t-SNE] Computed conditional probabilities for sample 153884 / 153884
# [t-SNE] Mean sigma: 0.450085
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 122.203377
# [t-SNE] KL divergence after 1000 iterations: 3.812284

# %%
tsne
# Out:
# array([[ -0.7665371, -24.315472 ],
#        [-21.295038 , -31.53738  ],
#        [ 33.33316  , -24.303823 ],
#        ...,
#        [-43.836998 ,  13.637594 ],
#        [-33.09258  ,   5.542834 ],
#        [ 24.52949  ,  26.554735 ]], dtype=float32)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(*zip(*tsne), c=y, cmap='PiYG_r', marker='+')
plt.show()
