# %% [markdown]
# # <center><b><h1>T-Test</h1></b></center>

# %%
import numpy as np
from scipy import stats
import pandas as pd

# %% [markdown]
# # 1. Prepare the data

# %%
patients = pd.read_csv("../Data/standardized_patients.csv", index_col=0, decimal=",")
patients = patients.astype(float)
patients.head()
# Out:
#         sex       age    weight    height     waist      HIPX  menopause  \
# 0 -1.029482  1.394174 -0.822174 -1.112304 -0.788439 -0.037838   1.436838
# 1  0.971362 -0.964756  1.052256  1.933924  0.269747 -0.037838  -0.695973
# 2 -1.029482 -1.337219 -0.567150 -0.894716 -0.410516 -0.037838  -0.695973
# 3  0.971362 -0.592293 -0.241993  1.063574 -0.108177 -0.037838  -0.695973
# 4  0.971362  0.400940 -0.280247  0.302016  0.496501 -0.037838  -0.695973
#
#         HRT   smoking  ReumatoidArthritis  ...     calcium  dose_walk  \
# 0  2.362657  0.760768            -0.08895  ...   -0.138433   0.675763
# 1 -0.423252 -0.808640            -0.08895  ...    0.754609  -0.225902
# 2 -0.423252  0.760768            -0.08895  ...    0.345527  -0.704564
# 3 -0.423252 -0.808640            -0.08895  ...   -0.060697  -0.619963
# 4 -0.423252 -0.808640            -0.08895  ...    0.213818  -0.326087
#
#    dose_moderate  dose_vigorous  dose_pleasure  dose_sport  dose_execise  \
# 0      -0.313105       0.201583       2.107507   -0.359069      1.836293
# 1      -0.387815      -0.353813      -1.169938   -0.359069     -0.865060
# 2      -0.611945      -0.538945      -1.169938   -0.359069     -0.865060
# 3      -0.537235      -0.538945      -0.383351   -0.359069     -0.865060
# 4      -0.499880      -0.538945      -1.169938   -0.359069     -0.865060
#
#    dose_lightDIY  dose_heavyDIY  Class
# 0      -0.789813      -0.654840    0.0
# 1       0.336362      -0.654840    0.0
# 2      -0.789813      -0.654840    0.0
# 3       1.212276       0.058338    0.0
# 4       0.336362      -0.654840    0.0
#
# [5 rows x 24 columns]

# %%
class_0 = patients[patients['Class'] == 1].copy()
class_1 = patients[patients['Class'] == 0].copy()

# %%
patients_stat = pd.DataFrame(columns=patients.columns.values[:-1])

patients_stat.at['t(𝑋𝑖)', :] = 0
patients_stat.at['p-value', :] = 0

# %%
for column in patients.columns.values[:-1]:
    patients_stat.at['t(𝑋𝑖)', column], patients_stat.at['p-value', column] = stats.ks_2samp(class_0[column], class_1[column])

# %%
patients_stat = patients_stat.T.sort_values(by=['p-value'], ascending=True)

# %%
patients_stat
# Out:
#                          t(𝑋𝑖)   p-value
# menopause             0.134357  0.000076
# age                   0.098404  0.008539
# height                0.071746  0.109978
# HRT                   0.071224  0.114701
# sex                   0.068605  0.140971
# VitaminD              0.062051  0.228130
# weight                0.060546  0.252985
# Alcohol               0.059826  0.265551
# smoking               0.059376  0.273648
# dose_pleasure         0.056253  0.334666
# calcium               0.044103  0.643586
# dose_vigorous         0.038246  0.804367
# dose_heavyDIY         0.037344  0.826923
# dose_lightDIY         0.035481  0.870130
# dose_walk             0.034347  0.893779
# waist                 0.033118  0.916791
# HIPX                  0.031000  0.949428
# dose_execise          0.028793  0.973637
# dose_moderate         0.027239  0.985010
# dose_sport            0.018692  0.999971
# SecondaryOsteoporsis  0.018309  0.999983
# Alcohol24             0.015348  1.000000
# ReumatoidArthritis    0.010154  1.000000

# %%
patients_stat.tail(10)
# Out:
#                          t(𝑋𝑖)   p-value
# dose_lightDIY         0.035481  0.870130
# dose_walk             0.034347  0.893779
# waist                 0.033118  0.916791
# HIPX                  0.031000  0.949428
# dose_execise          0.028793  0.973637
# dose_moderate         0.027239  0.985010
# dose_sport            0.018692  0.999971
# SecondaryOsteoporsis  0.018309  0.999983
# Alcohol24             0.015348  1.000000
# ReumatoidArthritis    0.010154  1.000000

# %%
patients_stat.to_csv("../Data/T-test.csv")
